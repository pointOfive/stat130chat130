# %% [markdown]
# #### Review  / Questions [20 minutes]
# 1. See Oct18 TUT and Oct21 LEC about Regression I
# 2. See Oct25 TUT and Nov04 LEC about Testing
#
# #### Demo [50 minutes]
# 1. Use ChatGPT to create a school related simulated dataset for multiple linear regression
#     1. Ensure ChatGPT provides binary, categorical, and "continuous" (`float` or `int`) data columns (very briefly reviewing types)
#     2. Review simple linear regression using [smf](https://www.statsmodels.org/dev/examples/notebooks/generated/formulas.html) [and not [sm](https://www.statsmodels.org/stable/api.html) which we won't use] for continuous and binary predictor variables
#     3. Introduce multiple linear regression using [smf](https://www.statsmodels.org/dev/examples/notebooks/generated/formulas.html) by
#         1. using both the continuous and binary variables
#         2. using a single (non-binary) categorical variable
#         3. using interaction with the continuous and binary variables
#         4. using interactions with the continuous and binary and categorical variables
#     4. Throughout the above demonstrations, show the formulas for multiple linear regression (expanding on the meaning of addition and interaction of _variables_)
#         1. Discuss the magnitude of an effect and belief in the statistical evidence of an affect
#         2. Visualize "best fit lines with interactions" using `px.scatter`
#
# #### Communication
#
# 1. **[5 minutes]** Break into 4 groups of 4-6 students and determine 1 person who could serve as a good protagonist for the exercises below.
#     1. **[10 minutes]** Come up with a story surrounding wanting to predict some outcome (*dependent variable*) about this person using 2 (or more) predictors (*independent variables*) that could be measured about the person. In doing so, the group should consider an interaction constructed from the variables as an additional predictor.
#       > For example: Good grade (dependent variable) might be affected by length of sleep (independent variable 1), time spent in studying (independent variable 2), and a combination of them (the new factor).
#       >
#       > That said, the more outrageous and entertaining the story your group can come up with, the funner it will be to present it to the other groups... humor is a powerful tool that you should try to add to any presentations you give (within reason and where possible)
#
#     2. **[25 minutes]** Present the story (in about 3 minutes per group) to other groups.
#         1. After each group presents, other groups should vote on whether the variables and interactions are appropiate, with there being about 3 minutes per group to discuss possible improvements to the prediction specification of proposed model
#
# #### Homework [0 minutes]
#
# > Code and write all your answers in a python notebook (in code and markdown cells) and save your python jupyter notebook in your own account and "repo" on [github.com](github.com) and submit a link to that notebook though Quercus for assignment marking.
#
# [MOVE QUESTSION 3 HERE AS QUESTION 1 (and reindex the questions)]
#
# > Imagine a company that sells sports equipment. The company runs advertising campaigns on TV and online platforms. The effectiveness of the TV ad might depend on the amount spent on online advertising and vice versa, leading to an interaction effect between the two advertising mediums.
#
# 1. Discuss with ChatGPT what the specific (outcome and predictor) variables are in this scenario and whether or not any meaningful interactions between them might need to be taken into account when predicting the outcome. Assuming potential interactions need to be considered, write down two formulas that represent modeling the interaction and not modeling the interaction. Try to write these formulas out (either as pseduomath or pseudocode expression) for yourself rather than just having ChatGPT provide them, but use ChatGPT to help you out if you need to.
#     1. Explain how to use thse two formluas to make predictions of the outcome, and interact with ChatGPT to help you write (draft, edit, and finalize) a high level explaination of why predictions from a model with an interaction are different than predictions from a model without an interaction.
#     2. Instead of considering an interaction between two continuous variables, consider an interaction between one of the continuous variales and a binary version of the other continuous variable which gets categorized as either simply having either a "low" or "high" numeric value; then, give an interpretation of the different predictions made by the interaction formula.
#
# 2. Find an interesting data set online for the scenario above, or for some other scenario in which you can analogously consider modeling interactions between continuos and indicator variables. Feel free to use help from ChatGPT wherever helpful for any part of this question.
#     1. Use `px.scatter` to plot "best fit lines" that show the observed effect of the interaction between a binary variable and a continuous variable under consideration, and describe in simple terms what the observed effect of the interaction appears to be
#     2. Use [smf](https://www.statsmodels.org/dev/examples/notebooks/generated/formulas.html) to fit an interaction model for your data and interpret what the statistical analysis of the model suggests regarding the evidence for the relevance of the interaction
#     3. Hypothetically supposing there was not sufficient evidence the relevance of the interaction, illustrate the approriate response through demonstration by providing an adjusted version of model specification and fit
#     4. Discuss if and how this "model building" process could be further applied to the remaining variables in the model specification
#
# 3. Discuss with ChatGPT the differences between simple linear regression and multiple linear regression and summarize your preference for one or the other and your rationale for this preference [MOVE THIS TO QUESTSION 1 (and reindex the questions)]
#     1. Discuss with ChatGPT the differences between using continuous variables, indicator variables, and interactions variables in multiple linear regression models, and succinctly summarize these distinctions in your own words
#     2. Discuss with ChatGPT the difference in how binary variables and non-binary categorical variables are encoded when used in multiple linear regression models, and explain in your own words what a "baseline group" is and why we use only "number of categories minus one" indicator variables for categorical variables in this context.
#
# 4. Ask ChatGPT whether the following OLS result shows a good fit, and extend your study on R-squared, F-statistic, AIC and BIC, and Coefficients and P-values. Try explaining in your own words how does each suggests a strong or a weak fit.
# ```
# OLS Regression Results
# Dep. Variable:	HP	R-squared:	0.176
# Model:	OLS	Adj. R-squared:	0.164
# Method:	Least Squares	F-statistic:	15.27
# Date:	Thu, 09 May 2024	Prob (F-statistic):	3.50e-27
# Time:	14:06:11	Log-Likelihood:	-3649.4
# No. Observations:	800	AIC:	7323.
# Df Residuals:	788	BIC:	7379.
# Df Model:	11
# Covariance Type:	nonrobust
# coef	std err	t	P>|t|	[0.025	0.975]
# Intercept	26.8971	5.246	5.127	0.000	16.599	37.195
# C(Generation)[T.2]	20.0449	7.821	2.563	0.011	4.692	35.398
# C(Generation)[T.3]	21.3662	6.998	3.053	0.002	7.629	35.103
# C(Generation)[T.4]	31.9575	8.235	3.881	0.000	15.793	48.122
# C(Generation)[T.5]	9.4926	7.883	1.204	0.229	-5.982	24.968
# C(Generation)[T.6]	22.2693	8.709	2.557	0.011	5.173	39.366
# Q("Sp. Def")	0.5634	0.071	7.906	0.000	0.423	0.703
# Q("Sp. Def"):C(Generation)[T.2]	-0.2350	0.101	-2.316	0.021	-0.434	-0.036
# Q("Sp. Def"):C(Generation)[T.3]	-0.3067	0.093	-3.300	0.001	-0.489	-0.124
# Q("Sp. Def"):C(Generation)[T.4]	-0.3790	0.105	-3.600	0.000	-0.586	-0.172
# Q("Sp. Def"):C(Generation)[T.5]	-0.0484	0.108	-0.447	0.655	-0.261	0.164
# Q("Sp. Def"):C(Generation)[T.6]	-0.3083	0.112	-2.756	0.006	-0.528	-0.089
# Omnibus:	337.229	Durbin-Watson:	1.505
# Prob(Omnibus):	0.000	Jarque-Bera (JB):	2871.522
# Skew:	1.684	Prob(JB):	0.00
# Kurtosis:	11.649	Cond. No.	1.40e+03
# ```
#
# 5. Discuss the following code with ChatGPT to make sure you understand how the code works.
# ```python
# from sklearn.model_selection import train_test_split
# songs_training_data,songs_testing_data = train_test_split(songs, train_size=31)
#
# reps = 100
# in_sample_Rsquared = np.array([0.0]*reps)
# out_of_sample_Rsquared = np.array([0.0]*reps)
# for i in range(reps):
#     songs_training_data,songs_testing_data = train_test_split(songs, train_size=31)
#     final_model_fit = smf.ols(formula='danceability ~ energy * loudness + energy * mode',
#                               data=songs_training_data).fit()
#     in_sample_Rsquared[i] = final_model_fit.rsquared
#     out_of_sample_Rsquared[i] = np.corrcoef(songs_testing_data.danceability,
#                                             final_model_fit.predict(songs_testing_data))[0,1]**2
#
# fig = px.scatter(pd.DataFrame({"In Sample Performance (Rsquared)": in_sample_Rsquared,
#                               "Out of Sample Performance (Rsquared)": out_of_sample_Rsquared}),
#                  x="In Sample Performance (Rsquared)", y="Out of Sample Performance (Rsquared)")
# fig.add_trace(go.Scatter(x=[0,1], y=[0,1], name="y=x", line_shape='linear'))
# ```
# 6. See if ChatGPT can suggest any streamlining, readability or usability improvements to the above code.
# 7. Explain what the function `train_test_split` do and what purpose for-loop is trying to achieve.
# 8. What issue of multiple linear regression does this code try to illustrate? Does this remind you of a popular field in computer science? If so, what is it?
