# %% [markdown]
# # Coding
#
# - `avatar.dtypes`, `df.col.str.upper()`, `+` and `.sum().split(' ')`
# - `for i in range(n)` and `for x in lst` and `for i,x in enumerate(lst)`
# - `list()` and `dict()`
# - `if`/`else`
# - $\Pr(\; Y=y\,|\,X=x\;)$
#     - $\Pr(\; W_{i+1}=w_{i+1}\,|\,W_i=w_i\;)$
#
# - Demonstrated but NOT TESTED
#     - $\Pr(\; W_{i+2}=w_{i+2}\,|\, W_{i+1}=w_{i+1}, W_i=w_i\;)$
#     - $\Pr(\; W_{i+3}=w_{i+3} \,|\, W_{i+2}=w_{i+2}, W_{i+1}=w_{i+1}, W_i=w_i\;)$
#     - $\Pr(\; W_{i+3}=w_{i+3} \,|\, W_{i+1}=w_{i+1}, W_i=w_i, C=c\;)$
#     - `np.array()` (from `import numpy as np`)
#     - `stats.multinomial(p=probability, n=attempts).rvs(size=1)[0,:]` (`from scipy import stats`)
#     - `.replace` and `import re` "regular expressions" ("regexp")

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-08-11/avatar.csv"
avatar = pd.read_csv(url) #avatar.isnull().sum() #avatar[avatar.isnull().sum(axis=1)>0]
avatar[:10]
# Out:
#    id   book  book_num                 chapter  chapter_num  \
# 0   1  Water         1  The Boy in the Iceberg            1
# 1   2  Water         1  The Boy in the Iceberg            1
# 2   3  Water         1  The Boy in the Iceberg            1
# 3   4  Water         1  The Boy in the Iceberg            1
# 4   5  Water         1  The Boy in the Iceberg            1
# 5   6  Water         1  The Boy in the Iceberg            1
# 6   7  Water         1  The Boy in the Iceberg            1
# 7   8  Water         1  The Boy in the Iceberg            1
# 8   9  Water         1  The Boy in the Iceberg            1
# 9  10  Water         1  The Boy in the Iceberg            1
#
#            character                                          full_text  \
# 0             Katara  Water. Earth. Fire. Air. My grandmother used t...
# 1  Scene Description  As the title card fades, the scene opens onto ...
# 2              Sokka  It's not getting away from me this time. [Clos...
# 3  Scene Description  The shot pans quickly from the boy to Katara, ...
# 4             Katara                  [Happily surprised.] Sokka, look!
# 5              Sokka  [Close-up of Sokka; whispering.] Sshh! Katara,...
# 6  Scene Description  Behind Sokka, Katara is still making circular ...
# 7             Katara  [Struggling with the water that passes right i...
# 8  Scene Description  The bubble containing her fish slowly drifts a...
# 9             Katara                       [Exclaims indignantly.] Hey!
#
#                                      character_words  \
# 0  Water. Earth. Fire. Air. My grandmother used t...
# 1                                                NaN
# 2  It's not getting away from me this time.  Watc...
# 3                                                NaN
# 4                                       Sokka, look!
# 5  Sshh! Katara, you're going to scare it away.  ...
# 6                                                NaN
# 7                          But, Sokka! I caught one!
# 8                                                NaN
# 9                                               Hey!
#
#                                               writer     director  imdb_rating
# 0  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 1  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 2  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 3  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 4  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 5  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 6  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 7  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 8  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 9  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1

# %%
avatar.dtypes
# Out:
# id                   int64
# book                object
# book_num             int64
# chapter             object
# chapter_num          int64
# character           object
# full_text           object
# character_words     object
# writer              object
# director            object
# imdb_rating        float64
# dtype: object

# %%
avatar.character.value_counts()#[:10]
# Out:
# character
# Scene Description    3393
# Aang                 1796
# Sokka                1639
# Katara               1437
# Zuko                  776
#                      ...
# The Hippo               1
# Audience                1
# Young Mai               1
# Old woman               1
# Katara and Sokka        1
# Name: count, Length: 374, dtype: int64

# %%
avatar.chapter.value_counts()#[:10]
# Out:
# chapter
# The Fortuneteller                          331
# The Warriors of Kyoshi                     304
# City of Walls and Secrets                  293
# Jet                                        290
# The Desert                                 286
#                                           ...
# The Siege of the North, Part 2             161
# Sozin's Comet, Part 3: Into the Inferno    151
# The Blue Spirit                            144
# Appa's Lost Days                           106
# Sozin's Comet, Part 4: Avatar Aang          91
# Name: count, Length: 61, dtype: int64

# %%
#words = ("\n"+avatar.dropna().character.str.upper()+": "+avatar.dropna().character_words+" ").sum().split(' ')
#words = ("\n"+avatar.dropna().character.str.upper()+": "+avatar.dropna().character_words+" ").sum().split(' ')
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# %%
#from collections import defaultdict
word_used = dict()#defaultdict(int)
next_word = dict()#defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-1]):
    
    if word in word_used:
        word_used[word] += 1
    else: 
        word_used[word] = 1
        next_word[word] = {}
        
    if words[i+1] in next_word[word]:
        next_word[word][words[i+1]] += 1 
    else:

        next_word[word][words[i+1]] = 1

# %%
next_word
# Out:
# {'\nKATARA:': {'Water.': 2,
#   '[Happily': 1,
#   '[Struggling': 2,
#   '[Exclaims': 1,
#   '[Cut': 13,
#   'Watch': 1,
#   '[A': 3,
#   '[Indignantly.]': 1,
#   'You': 34,
#   'Ever': 1,
#   '[Close-up': 8,
#   'No': 8,
#   '[Astonished.]': 1,
#   "He's": 5,
#   '[Waves': 2,
#   'What?': 7,
#   '[Curiously.]': 4,
#   '[Awkwardly.]': 2,
#   '[Pushes': 1,
#   '[Gasps': 1,
#   "We'd": 2,
#   '[While': 2,
#   '[Uncomfortably.]': 1,
#   'Hey.': 2,
#   'I': 76,
#   'Okay.': 2,
#   'Aang?': 4,
#   'Aang,': 39,
#   '[Gesturing.]': 1,
#   '[Offering': 1,
#   '[Nervously.]': 5,
#   '[Excitedly.]': 11,
#   'But': 18,
#   '[Runs': 1,
#   '[Amused.]': 3,
#   '[Sadly.]': 4,
#   'Maybe,': 1,
#   '[Unsure.]': 2,
#   '[Mockingly': 2,
#   '[Happily.]': 2,
#   '[On': 1,
#   '[Her': 1,
#   'Think': 2,
#   '[Squats': 1,
#   '[Smiling': 3,
#   'Aaah!': 1,
#   '[Protesting.]': 1,
#   '[Irritably,': 1,
#   '[Angrily.]': 17,
#   '[Pleading.]': 3,
#   '[Outraged.]': 1,
#   '[Upset.]': 2,
#   '[Still': 4,
#   '[Rounding': 1,
#   '[Hysterically.]': 1,
#   '[Surprised.]': 10,
#   '[Sokka': 2,
#   '[Making': 1,
#   '[Running': 2,
#   '[Annoyed.]': 7,
#   '[Pointing': 6,
#   '[Brightly.]': 2,
#   '[Pleading': 1,
#   'Sokka': 4,
#   '[Thrilled.]': 1,
#   '[Horrified.]': 3,
#   '[Voice-over.]': 8,
#   '[Shocked.]': 6,
#   '[Worried.]': 8,
#   '[Urgently.]': 1,
#   '[Bewildered.]': 1,
#   '[Curious,': 1,
#   'According': 1,
#   '[Brightening': 1,
#   '[Faces': 1,
#   '[Optimistically.]': 1,
#   '[Cautiously.]': 3,
#   '[Uneasily.]': 1,
#   '[Places': 1,
#   '[Irritated.]': 7,
#   "What's": 4,
#   'Fire': 1,
#   '[Yelling.]': 4,
#   '[Innocently': 1,
#   '[Understandingly': 1,
#   '[Curious.]': 1,
#   '[Touching': 1,
#   'Who': 2,
#   '[Camera': 4,
#   '[Understanding.]': 1,
#   "It's": 26,
#   'Aang!': 7,
#   '[She': 4,
#   '[Looks': 10,
#   '[Irritably.]': 1,
#   '[Shouting': 1,
#   'Oh': 5,
#   '[In': 5,
#   "Everything's": 2,
#   'Maybe': 10,
#   '[Aang': 5,
#   '[Nonchalantly,': 1,
#   '[Close': 1,
#   '[Suddenly': 2,
#   '[Smiling.]': 4,
#   '[Notices': 2,
#   'Get': 3,
#   'What': 29,
#   '[Leans': 2,
#   '[Puts': 3,
#   '[Glancing': 2,
#   'Hey,': 7,
#   'Well,': 11,
#   '[Turns': 9,
#   '[Slightly': 8,
#   '[Resumed': 1,
#   '[Sarcastic.]': 1,
#   '[Close-up;': 2,
#   '[Turning': 2,
#   '[Slants': 1,
#   '[Growing': 3,
#   '[Angry.]': 1,
#   '[Somewhat': 4,
#   '[Smiling.': 2,
#   '[Carefully': 1,
#   '[Worriedly.]': 3,
#   'Then': 5,
#   '[Peeking': 1,
#   '[Shocked;': 2,
#   '[Stretching': 1,
#   '[Waving.]': 1,
#   '[Lightheartedly.]': 1,
#   '[Uneasy.]': 1,
#   '[Scared.]': 2,
#   '[Quietly': 1,
#   '[Accusingly.]': 1,
#   'This': 13,
#   '[Determined.]': 6,
#   '[Climbing': 1,
#   'Other': 1,
#   "We're": 11,
#   'And': 8,
#   '[The': 2,
#   'Uh,': 4,
#   'So': 9,
#   'Seriously': 1,
#   'An': 1,
#   '[Shrugging.]': 1,
#   '[Enters': 2,
#   'How': 7,
#   "I'm": 23,
#   '[Flattered.]': 1,
#   'He': 4,
#   '[Sits': 3,
#   'No.': 2,
#   '[Haru': 1,
#   '[Getting': 1,
#   'Please,': 1,
#   'It': 11,
#   '[Unhappily.]': 1,
#   '[Slyly,': 1,
#   '[Hurriedly.]': 1,
#   "Haru's": 1,
#   '[Props': 2,
#   '[Angrily': 1,
#   '[Far': 1,
#   '[More': 1,
#   "I'll": 5,
#   '[Excitedly.': 1,
#   'If': 2,
#   '[Obstinately.]': 1,
#   'Earthbenders!': 1,
#   'We': 12,
#   '[Sternly.]': 1,
#   '[Lays': 2,
#   '[Lifting': 1,
#   'So,': 7,
#   '[Voice-over;': 1,
#   'Shhh!': 2,
#   "That's": 15,
#   '[Approaches': 3,
#   'These': 4,
#   'Hey': 3,
#   '[With': 3,
#   'Aang': 3,
#   'Sokka,': 17,
#   "You're": 16,
#   'Sokka!': 5,
#   '[Desperately.]': 2,
#   '[Looking': 6,
#   '[Aang,': 1,
#   "There's": 4,
#   '[Smiles': 3,
#   '[Impressed.]': 1,
#   '[Hides': 1,
#   '[Presses': 1,
#   '[Chained.': 1,
#   '[Pleased.]': 2,
#   'Not': 5,
#   '[': 1,
#   '[Grabs': 3,
#   '[Nods': 1,
#   '[Kindly.]': 1,
#   '[Smiles.]': 3,
#   '[Angry': 1,
#   '[Whispering.]': 2,
#   '[Worried,': 2,
#   '[Mischievously.]': 1,
#   '[Excited.]': 3,
#   '[Jokingly.]': 2,
#   '[Glaring': 1,
#   '[Screaming.]': 1,
#   '[Bends': 1,
#   '[Furiously.]': 2,
#   'My': 3,
#   'No!': 2,
#   'Thanks,': 1,
#   'Help': 1,
#   'Everybody': 1,
#   '[Pointing.]': 1,
#   'Besides,': 1,
#   'The': 11,
#   'Stealing': 1,
#   'Why': 10,
#   '[Back': 1,
#   '[Sarcastically.]': 13,
#   '[Whispers.]': 2,
#   '[Points': 2,
#   'Hi.': 1,
#   '[Approaching': 6,
#   '[Eyeing': 1,
#   '[Very': 1,
#   '[As': 3,
#   "Don't": 9,
#   'No,': 11,
#   'See,': 1,
#   'Well': 2,
#   'Jet,': 2,
#   'Yeah,': 2,
#   "I've": 3,
#   'When': 1,
#   "Let's": 5,
#   '[Less': 2,
#   "Where's": 1,
#   'Why,': 1,
#   'Come': 6,
#   'All': 4,
#   'Goodbye': 1,
#   'Let': 1,
#   'Um,': 1,
#   'Sounds': 1,
#   'Ooh,': 2,
#   'Is': 5,
#   '[Over': 1,
#   '[Stepping': 2,
#   'Your': 2,
#   '[Hesitates.]': 1,
#   '[Frontal': 6,
#   '[Shot': 2,
#   '[Shaking': 1,
#   'Whoa!': 1,
#   'Where': 2,
#   'Really?': 2,
#   '[Pressing': 1,
#   'Relax,': 2,
#   '[Also': 1,
#   '[Weakly.]': 1,
#   '[Weakly;': 1,
#   '[Off-camera.]': 1,
#   '[Cups': 1,
#   'That': 7,
#   '[Smugly.]': 1,
#   'Just': 3,
#   'Try': 1,
#   '[Rising': 1,
#   'Actually,': 3,
#   '[Satisfied.]': 1,
#   'Why?': 1,
#   '[Laying': 1,
#   'Hi,': 2,
#   'About': 1,
#   'Yes,': 3,
#   '[Lifts': 1,
#   'Okay,': 5,
#   '[Kicks': 1,
#   '[Half-heartedly.]': 1,
#   'Uh': 1,
#   '[Begins': 2,
#   '[Dismayed.]': 2,
#   '[Reading': 2,
#   'Wait,': 1,
#   '[Slowly': 1,
#   '[Holding': 5,
#   '[Cheerfully.]': 4,
#   'Bato,': 2,
#   '[Surprised': 1,
#   'Everyone': 2,
#   '[To': 5,
#   'Even': 1,
#   'Of': 1,
#   '[Concerned.]': 2,
#   'Good': 1,
#   'Sokka?': 1,
#   '[Takes': 4,
#   'Aw,': 1,
#   '[Walking': 2,
#   '[Stares': 1,
#   '[Swayed': 1,
#   '[Starts': 2,
#   "You'll": 2,
#   'By': 1,
#   '[Moving': 3,
#   '[Crossing': 1,
#   '[Amazed.]': 1,
#   '[Katara': 2,
#   '[Walks': 7,
#   '[Pokes': 1,
#   'Teo': 1,
#   'Wait!': 2,
#   'Ugh,': 1,
#   'Huh,': 1,
#   'Those': 2,
#   'Water?': 1,
#   '[Waving': 2,
#   "They're": 2,
#   '[Fascinated.]': 1,
#   '[Hopping': 1,
#   'Very': 1,
#   '[Furious.]': 1,
#   'Uhhh': 2,
#   'Thanks': 3,
#   'Huh?': 1,
#   '[Confused.]': 3,
#   'She': 3,
#   "How's": 1,
#   '[Bending': 2,
#   'Yes': 1,
#   'Fine.': 1,
#   '[Unfreezing': 1,
#   'You,': 1,
#   '[Alarmed': 1,
#   '[Off-screen;': 1,
#   'Look,': 2,
#   '[Confidently': 1,
#   'Do': 3,
#   '[Accepts': 1,
#   '[Holds': 2,
#   '[Rises': 4,
#   'Can': 2,
#   '[Cuts': 5,
#   '[Frantically.]': 3,
#   '[Casts': 1,
#   '[Proudly.]': 1,
#   "Sokka's": 3,
#   '[Hold': 1,
#   '[Hesitant.': 1,
#   '[Shyly,': 1,
#   'See?': 1,
#   '[Fake-jokingly.]': 1,
#   '[Insulted.]': 1,
#   '[Disgusted.]': 1,
#   '[Enraged.]': 1,
#   'Sorry.': 2,
#   '[Baby': 1,
#   'Does': 3,
#   "We've": 3,
#   '[Crosses': 4,
#   '[Calling': 1,
#   'Hello?': 1,
#   'Okay': 1,
#   '[Grabbing': 1,
#   '[Aiding': 1,
#   '[Excitedly': 1,
#   '[Gently': 1,
#   'Oyaji!': 1,
#   '[Approvingly.]': 1,
#   '[Squatting': 1,
#   '[Realizing': 1,
#   '[Unimpressed.]': 1,
#   'They': 4,
#   'Honorable': 1,
#   'Mayor': 1,
#   '[Hopeful.]': 3,
#   '[Begging.]': 1,
#   'Happy': 1,
#   '[Consolingly': 1,
#   '[Sighs': 1,
#   '[Slaps': 1,
#   '[Glares': 2,
#   '[Cutting': 1,
#   '"If': 1,
#   'Toph,': 3,
#   '[Displeased,': 1,
#   '[Wiping': 2,
#   '[Rubs': 1,
#   'Should': 1,
#   '[Curtly.]': 1,
#   '"Both"?!': 1,
#   '[Mockingly.]': 2,
#   'Seriously,': 1,
#   '[Angrily;': 1,
#   '[Alarmed.]': 1,
#   'Are': 6,
#   'Every': 1,
#   '[Regretfully.]': 1,
#   'Zuko,': 2,
#   '[Trying': 1,
#   'Sorry': 1,
#   '[Examines': 1,
#   '[Sheepishly.]': 1,
#   '[Sand': 1,
#   'Hurry,': 1,
#   '[Sad': 1,
#   '[Backing': 1,
#   '[Wrapping': 1,
#   '[Encouraging.]': 1,
#   '[Disappointed.]': 1,
#   'Trying': 1,
#   'A': 3,
#   'Yes.': 3,
#   'On': 1,
#   '[Quietly.]': 1,
#   'Great!': 1,
#   'Hmm': 2,
#   'Appa': 1,
#   '[From': 1,
#   "She's": 1,
#   'His': 1,
#   '[Eyes': 1,
#   'Yes?': 1,
#   '[Appears': 2,
#   '[Explodes': 1,
#   '[Panting': 1,
#   'Wait.': 1,
#   '[Reads': 2,
#   '[Hatefully': 1,
#   '[Unamused.]': 1,
#   '[Sympathetically.]': 1,
#   '[Nervous': 1,
#   '[Close-up.]': 1,
#   '[Tight': 1,
#   '[Side-view': 2,
#   '[Side-view.]': 1,
#   '[View': 1,
#   '[Side-view.': 1,
#   'Toph!': 1,
#   "It'll": 1,
#   'Now': 2,
#   'Ow!': 1,
#   "Jet's": 1,
#   '[Preparing': 1,
#   'Gee,': 2,
#   'Close': 1,
#   'One': 2,
#   '[Thinks': 1,
#   '[Water': 1,
#   'Sorry!': 1,
#   '[Opens': 2,
#   'Easy': 2,
#   '[Hugs': 2,
#   'Or': 2,
#   'Thank': 1,
#   'Zuko!': 1,
#   '[Continuing': 1,
#   '[Apologetic.]': 1,
#   '[Placing': 3,
#   'Great,': 1,
#   '[Confused': 1,
#   'Tell': 1,
#   '[During': 1,
#   '[Exiting.]': 1,
#   'Aang.': 1,
#   '[Embraces': 1,
#   'Oh,': 6,
#   '[Concernedly.]': 1,
#   'Sapphire': 1,
#   '[Barely': 1,
#   '[Chases': 1,
#   '[Reluctantly.]': 1,
#   '[Touched.]': 1,
#   'Forty-three': 1,
#   'Looks': 1,
#   '[Gets': 1,
#   '[Using': 2,
#   '[Giggles': 1,
#   '[Guiltily.]': 1,
#   '[Defensively.]': 1,
#   'Leave': 1,
#   'Wow,': 2,
#   '[Jumps': 2,
#   'Yeah': 1,
#   '[Sitting': 1,
#   'Ah,': 1,
#   'Guys,': 1,
#   'Ah.': 1,
#   '[Slides': 1,
#   '[Pauses': 1,
#   '[Unpacking': 1,
#   '[Stunned.]': 1,
#   '[Delighted.]': 1,
#   'Yes!': 1,
#   '[Widens': 1,
#   '[Tearfully.]': 1,
#   'Nice': 1,
#   '[Putting': 1,
#   'Good,': 1,
#   '[Approaching.]': 1,
#   '[After': 1,
#   '[Initially': 1,
#   '[Speaking': 1,
#   'Dad?': 1,
#   '[Quizzically.]': 1,
#   '[Stopping': 1,
#   '[Doubtful.]': 1,
#   'Appa,': 1,
#   "We'll": 1,
#   '[Handing': 1,
#   '[Approaching,': 1,
#   'Zuko?': 1,
#   '[Following.': 1,
#   'Sure.': 1,
#   'Right': 1,
#   '"Need': 1,
#   '[Tearing': 1,
#   '[Brushing': 1,
#   '[Shakes': 1,
#   '[Clutches': 1,
#   '[Sorrowfully.]': 1,
#   "Doesn't": 1,
#   '[Complacently': 1,
#   'In': 1,
#   'Because,': 1,
#   '[Sinks': 1,
#   '[Pulls': 1,
#   '[Zuko': 1,
#   'Goodbye,': 1},
#  'Water.': {'Earth.': 2, '[Shot': 1},
#  'Earth.': {'Fire.': 2, '\nSCENE_DESCRIPTION:': 1, '[Shot': 1, 'Zuko': 1},
#  'Fire.': {'Air.': 2, 'Wang': 1, '[Pointing': 1, 'Nice': 1, '[Shot': 1},
#  'Air.': {'My': 1, 'Long': 1, '[Shot': 1},
#  'My': {'grandmother': 2,
#   'watchtower!': 1,
#   'staff!': 2,
#   'fault,': 1,
#   'ancient': 1,
#   'search': 1,
#   'brother': 5,
#   'cabbages!': 5,
#   'business': 1,
#   'liege,': 1,
#   'mom': 2,
#   'father': 9,
#   'mother': 3,
#   'family': 1,
#   "mother's": 2,
#   'troubles': 1,
#   'village': 1,
#   'name': 8,
#   "name's": 9,
#   "Uncle's": 1,
#   'old': 3,
#   'life': 4,
#   'boat!': 1,
#   'whole': 2,
#   'joints': 1,
#   'nephew': 1,
#   'people': 1,
#   'request': 1,
#   'honor,': 1,
#   'friends': 2,
#   'frogs!': 1,
#   'shirshu': 1,
#   'infant': 1,
#   'apologies,': 2,
#   'friend': 1,
#   'Gran-Gran': 1,
#   'fleet': 1,
#   'dark': 1,
#   'daughter': 2,
#   'lucky': 1,
#   'scrolls!': 1,
#   'parents': 2,
#   'dad': 6,
#   'first': 2,
#   'pleasure.': 1,
#   'beloved': 1,
#   "life's": 1,
#   'word!': 1,
#   'cabba-': 1,
#   'uncle': 5,
#   'own': 3,
#   "mom's": 1,
#   'most': 1,
#   'Fire': 1,
#   'sister!': 1,
#   'face?': 1,
#   'goodness!': 1,
#   'brother,': 1,
#   "dad's": 1,
#   'earthbending': 1,
#   'cell': 1,
#   'bending': 2,
#   'work': 1,
#   'form': 1,
#   'royal': 1,
#   'instincts': 1,
#   'father,': 2,
#   'favorite': 1,
#   'feet': 2,
#   'great-grandfather': 1,
#   'guess': 1,
#   'sister': 1,
#   'source': 1,
#   'jokes': 1,
#   'heart': 1,
#   'stomach': 1,
#   'hero!': 1,
#   'uncle,': 1,
#   'decision': 1,
#   'leg!': 1,
#   'hair': 1},
#  'grandmother': {'used': 1, 'into': 1, 'gave': 1, 'had': 1, 'when': 1},
#  'used': {'to': 40,
#   'it': 5,
#   'as': 2,
#   'that': 1,
#   'bending': 1,
#   'in': 1,
#   'for': 3,
#   'this': 1,
#   'the': 1,
#   'by': 1,
#   'its': 1,
#   'earthbending': 1,
#   'my': 1,
#   'up': 1,
#   'to.': 1,
#   'firebending': 1,
#   'fear': 1},
#  'to': {'tell': 37,
#   'the': 1699,
#   'help': 58,
#   'look': 85,
#   'save': 26,
#   'another': 35,
#   'it,': 5,
#   'an': 242,
#   'a': 1458,
#   'Katara,': 28,
#   'his': 201,
#   'her': 69,
#   'surprise;': 1,
#   'where': 79,
#   'move': 34,
#   'ripple.': 1,
#   'scare': 2,
#   'control': 15,
#   'hang': 3,
#   'strike': 23,
#   'lose': 10,
#   'our': 12,
#   'myself.': 1,
#   'him,': 17,
#   'face': 105,
#   'keep': 44,
#   'stay': 21,
#   'gain': 5,
#   "Katara's": 11,
#   'Sokka.': 11,
#   'reveal': 111,
#   'screw': 1,
#   'be': 255,
#   'you!': 5,
#   'show': 341,
#   'herself.]': 4,
#   'snake': 1,
#   'fall': 38,
#   '"freakish",': 1,
#   'glow': 8,
#   'one': 30,
#   'rest\xa0with': 1,
#   'hold': 18,
#   'help!': 4,
#   'growl': 2,
#   'finish': 10,
#   'come': 36,
#   'get': 181,
#   'capture': 14,
#   'settle.': 1,
#   'their': 18,
#   'defend': 15,
#   'catch': 24,
#   'poke': 1,
#   'ask': 5,
#   'lift': 12,
#   'react': 3,
#   'Aang,': 88,
#   'inhale': 1,
#   'happen,': 2,
#   'frantically': 2,
#   'see': 168,
#   'signal': 4,
#   'death?': 1,
#   'retaliate,': 1,
#   'make': 76,
#   'bed': 1,
#   'Appa': 47,
#   'have': 45,
#   'meet': 33,
#   'dress': 1,
#   'Katara': 65,
#   'examine': 6,
#   'cover': 16,
#   'soar': 3,
#   'further': 2,
#   'extricate': 1,
#   'pull': 14,
#   'pat': 1,
#   'retract': 1,
#   'let': 19,
#   'teach': 17,
#   'put': 21,
#   'my': 34,
#   "Aang's": 30,
#   'yank': 3,
#   "Zuko's": 29,
#   'them.': 11,
#   'duck': 3,
#   'aim': 1,
#   'emphasize': 11,
#   'master': 15,
#   'stop': 60,
#   'and': 9,
#   'defeat': 9,
#   'yell': 1,
#   'six': 1,
#   'go?': 6,
#   'Sokka': 94,
#   'walk': 34,
#   'cross': 4,
#   'Aang.]': 36,
#   'enthusiasm': 1,
#   'think': 23,
#   'find': 100,
#   'propel': 7,
#   'land': 16,
#   'Aang': 156,
#   'pass': 4,
#   'race': 2,
#   'approach': 3,
#   'go': 54,
#   'climb': 9,
#   'inspect': 6,
#   'you?': 10,
#   'floor': 1,
#   'all': 5,
#   'function.': 1,
#   'jump': 10,
#   'Prince': 3,
#   'credits.': 55,
#   'learn': 24,
#   'him': 53,
#   'us,': 3,
#   'sadly': 1,
#   'Dad.': 1,
#   'that.': 1,
#   'hop': 1,
#   'stand': 17,
#   'prepare': 5,
#   'quake': 1,
#   'flee': 5,
#   'safety': 1,
#   'view': 47,
#   'strike.': 3,
#   'shot': 311,
#   'free': 9,
#   'dart': 1,
#   'miss': 7,
#   'overhead': 54,
#   'ward': 3,
#   'continue': 4,
#   'leave': 30,
#   'later': 10,
#   'repair': 1,
#   'act': 12,
#   'life,': 1,
#   'Sokka.]': 20,
#   'your': 27,
#   'Iroh.]': 9,
#   'compartment': 1,
#   'unlock': 3,
#   'on': 5,
#   'play': 11,
#   'attack': 30,
#   'escape,': 3,
#   'cut': 15,
#   'various': 2,
#   'slow': 9,
#   'corner': 1,
#   'avoid': 31,
#   'Zuko': 90,
#   'roll': 5,
#   'inside': 42,
#   'try': 24,
#   'ride': 5,
#   'dissipate': 2,
#   'grab': 27,
#   'maintain': 4,
#   'deflect': 14,
#   'regain': 8,
#   'fire': 7,
#   'close-up': 89,
#   'glow.': 2,
#   'grasp': 2,
#   'Appa,': 19,
#   'three': 14,
#   'whip': 2,
#   'her,': 8,
#   'himself,': 2,
#   'chip': 1,
#   'break': 28,
#   'heft': 1,
#   'redirect': 7,
#   'begin': 8,
#   'Zuko,': 29,
#   'melt': 2,
#   'set.': 1,
#   'be.': 11,
#   'return': 4,
#   'this': 13,
#   'do': 121,
#   'legend,': 2,
#   'first': 1,
#   'knock': 15,
#   'attend': 3,
#   'situate': 1,
#   "Appa's": 19,
#   "Sokka's": 19,
#   'each': 23,
#   'go.': 14,
#   'join': 17,
#   'pour': 3,
#   'start': 15,
#   'some': 13,
#   'talk': 37,
#   'you': 15,
#   'accept.': 1,
#   'temper': 1,
#   "Zhao's": 4,
#   'Zhao.': 1,
#   'eat?': 3,
#   'ever': 2,
#   'distract': 3,
#   'side': 12,
#   'Sokka,': 33,
#   'see.': 2,
#   'them': 14,
#   'see!': 1,
#   'spin': 5,
#   'enter': 3,
#   'shift': 3,
#   'you.': 23,
#   'stuff': 5,
#   'meet.': 2,
#   'Katara;': 3,
#   'drool': 1,
#   'push': 18,
#   'purple': 1,
#   'open.': 3,
#   'Zuko.]': 14,
#   'him.': 50,
#   'that': 11,
#   'eat': 9,
#   'run': 20,
#   'sea,': 1,
#   'Zhao,': 9,
#   'laugh': 4,
#   'slowly': 1,
#   'prove': 10,
#   'match!': 1,
#   'watch': 16,
#   'somewhere': 2,
#   'follow': 33,
#   'several': 5,
#   'behind': 27,
#   'gleam.': 1,
#   'statue': 1,
#   'gleam': 1,
#   'fright.': 1,
#   'form.': 2,
#   'protect': 28,
#   'Aang.': 27,
#   'rise': 11,
#   'Zhao': 10,
#   'lower': 3,
#   'Iroh,': 11,
#   'both': 7,
#   'deliver': 5,
#   'throw': 11,
#   'charge': 6,
#   'descend.': 4,
#   'die': 3,
#   'him?': 4,
#   'stick': 4,
#   'name': 3,
#   'take': 55,
#   'nibble': 1,
#   'portray': 3,
#   'frontal': 75,
#   'side-view': 77,
#   'say,': 4,
#   'cool': 2,
#   'track': 4,
#   'impress': 5,
#   'sew.': 1,
#   'shoo': 2,
#   'give': 20,
#   'close': 8,
#   'argue': 3,
#   'disrobe': 1,
#   'off': 1,
#   'leap': 2,
#   'exit': 3,
#   'suddenly': 1,
#   'wide-open': 1,
#   'wide-view': 14,
#   'hit': 12,
#   'do.': 11,
#   "Oyaji's": 1,
#   'Unagi!': 1,
#   'counter': 1,
#   'snap': 1,
#   'emit': 1,
#   'foam,': 1,
#   'focus': 8,
#   'treat': 2,
#   'Katara.]': 24,
#   'Sokka;': 2,
#   'himself.]': 6,
#   'snatch.': 1,
#   "Momo's": 1,
#   'right.': 1,
#   'right': 5,
#   'no': 2,
#   'it.': 12,
#   'interrupt': 3,
#   'block': 18,
#   'punch': 3,
#   'wave': 2,
#   'draw': 7,
#   'fob': 1,
#   'ferociously': 1,
#   'act.]': 1,
#   'wear': 5,
#   'practice': 6,
#   'evade': 3,
#   'battle': 3,
#   'circle': 6,
#   'entertain': 1,
#   'swing': 7,
#   'snatch': 1,
#   'side,': 3,
#   'reach': 6,
#   'head': 7,
#   'right,': 2,
#   'fight': 34,
#   'decimate': 1,
#   'create': 24,
#   'blast': 3,
#   'her.': 18,
#   'Katara.': 7,
#   'run,': 5,
#   'say': 22,
#   'Suki': 4,
#   'fight.]': 3,
#   'address': 3,
#   'gush': 1,
#   'always': 2,
#   'visit': 5,
#   'slide': 5,
#   'do?': 12,
#   "skippin',": 1,
#   'Omashu.': 5,
#   'end': 12,
#   'love': 3,
#   'front': 3,
#   '[Close-up': 1,
#   'disbelief': 1,
#   'drop': 3,
#   'them,': 4,
#   'regular': 1,
#   'four': 3,
#   'change': 8,
#   'two': 15,
#   'receive': 2,
#   'him.]': 22,
#   'see,': 1,
#   'open': 13,
#   'present': 11,
#   'rock': 1,
#   'combat': 1,
#   'check': 8,
#   'pieces': 3,
#   'guards': 1,
#   'black': 5,
#   'Bumi.]': 1,
#   'fit': 2,
#   'Momo': 8,
#   'its': 12,
#   'them.]': 7,
#   'remove': 4,
#   'engulf': 1,
#   'me.': 31,
#   'Bumi': 4,
#   'Bumi.': 2,
#   'fight?': 2,
#   'helicopter': 1,
#   'accelerate': 2,
#   'collide': 3,
#   'sand': 1,
#   'know': 26,
#   'restore': 7,
#   'learn.': 4,
#   'herself': 1,
#   'control.': 1,
#   'fuel': 2,
#   'earthbend': 3,
#   'waterbend.': 2,
#   'late': 1,
#   'stare': 11,
#   'chew': 1,
#   'one.': 1,
#   'sand\xa0with': 1,
#   'use': 26,
#   'waterbend,': 1,
#   'Haru.': 1,
#   'arrest': 1,
#   'which': 4,
#   'stealthily': 1,
#   'welcome': 4,
#   'rescue': 3,
#   'hope': 2,
#   'survive.': 3,
#   'sleep': 4,
#   'bend.': 2,
#   'dig,': 1,
#   'black.': 1,
#   'leave,': 10,
#   'fly': 20,
#   'smokestacks.]': 1,
#   'go,': 4,
#   'bend': 12,
#   'halt': 7,
#   'haul': 2,
#   'collect': 3,
#   'him.\nTyro': 1,
#   'compress': 1,
#   'thank': 5,
#   'fall,': 1,
#   'search': 5,
#   'rest': 3,
#   'something': 2,
#   'leave!': 2,
#   'go!': 6,
#   'do,': 6,
#   'resolve': 3,
#   'try,': 1,
#   'Senlin,': 1,
#   'please': 3,
#   'help.': 11,
#   'turn': 9,
#   'pursue': 1,
#   'it': 4,
#   'Senlin': 1,
#   'notice': 4,
#   'me!': 8,
#   'Roku?': 2,
#   'Roku!': 1,
#   'Iroh.': 3,
#   'scream': 4,
#   'me': 9,
#   'appear.': 1,
#   'speak': 10,
#   'Iroh': 19,
#   'night.': 3,
#   'Senlin.': 1,
#   'resume': 2,
#   'repay': 1,
#   'Roku': 16,
#   'contact': 1,
#   'move,': 2,
#   'Avatar': 7,
#   'leave.': 9,
#   'fire.': 1,
#   'come!': 1,
#   'spot': 2,
#   'forward': 1,
#   'plunge': 1,
#   'just': 1,
#   'apprehend': 2,
#   'glide': 1,
#   'work': 7,
#   'Appa.': 9,
#   'Momo.': 2,
#   'chase': 6,
#   'trust': 10,
#   'glow!': 1,
#   'return.': 1,
#   'serve': 8,
#   'betray': 1,
#   'light': 6,
#   'blind': 2,
#   'reclaim': 1,
#   'send': 17,
#   'Roku.': 3,
#   'Shyu,': 1,
#   'mention': 4,
#   'survive,': 1,
#   'destroy': 15,
#   'erupt': 1,
#   'lean,': 1,
#   'support': 3,
#   'splash': 1,
#   'perfect.': 1,
#   'figure': 5,
#   'replace': 2,
#   'Oh,': 1,
#   'deal': 4,
#   'haggle.': 1,
#   'outside,': 2,
#   'browse': 1,
#   'trade': 1,
#   'it.]': 2,
#   'peaceful': 1,
#   'taste': 1,
#   'kind': 1,
#   'pirates,': 1,
#   'hack': 1,
#   'bending': 1,
#   'pet': 1,
#   'stop.': 6,
#   'sleep.': 8,
#   'perfect': 1,
#   'understand.': 3,
#   'kidnap?': 1,
#   'leave.]': 8,
#   'fight.': 7,
#   'cuts': 1,
#   'budge': 2,
#   'Team': 21,
#   'safety.]': 1,
#   'simply': 1,
#   'upward': 1,
#   'pack': 1,
#   'carry': 2,
#   'hurt': 9,
#   'Pipsqueak.]': 1,
#   'ambush': 1,
#   'mess': 2,
#   'Longshot': 1,
#   'steal': 4,
#   'worry': 11,
#   'crawl': 3,
#   'kick': 3,
#   'Momo,': 5,
#   'Jet': 8,
#   'eliminate': 1,
#   'fill': 1,
#   'burn': 5,
#   'blow': 6,
#   'rid': 2,
#   'down': 1,
#   'escape': 13,
#   'flow': 2,
#   'think.': 5,
#   'anyone': 2,
#   'understand': 3,
#   'hook;': 1,
#   'if': 1,
#   'neck.': 1,
#   'me,': 5,
#   'Jet.]': 2,
#   'assemble': 1,
#   'slice': 9,
#   'flee!': 1,
#   'be.]': 1,
#   'shout': 1,
#   'illustrate': 1,
#   'tower': 1,
#   'amplify': 1,
#   'form': 9,
#   'become': 6,
#   'Zhangs.]': 1,
#   'nightfall,': 2,
#   'bring': 12,
#   'tend': 1,
#   'twenty': 1,
#   'Zhang': 1,
#   'flee.]': 1,
#   'guide': 6,
#   'share': 4,
#   'shock.': 1,
#   'Gyatso,': 2,
#   'raise': 6,
#   'shield': 5,
#   'reality': 1,
#   'shoot': 15,
#   'hear': 22,
#   'waves': 1,
#   'normal': 4,
#   'adjusting': 1,
#   'downward': 1,
#   'him;': 4,
#   'panic': 1,
#   "Jee's": 1,
#   'everyone': 1,
#   'firebend.': 3,
#   'him!': 2,
#   'backpedal': 1,
#   'balance': 1,
#   'when': 6,
#   'Avatars': 1,
#   'know?': 3,
#   'rule': 1,
#   'speak.': 3,
#   'Iroh.]\xa0Thank': 1,
#   'feel': 8,
#   'flashback.': 1,
#   'duel': 2,
#   'flashback': 4,
#   'Monk': 1,
#   'grow': 3,
#   'complete': 5,
#   'say.': 5,
#   'me?': 8,
#   'Gyatso': 2,
#   'Zuko.': 14,
#   'waiver.]': 1,
#   'shake.]\xa0and': 1,
#   'fight,': 5,
#   'normal.': 5,
#   'fall.': 8,
#   'safety.': 4,
#   'die!': 2,
#   'apologize.': 4,
#   'pay': 2,
#   'Zhao;': 1,
#   'Admiral.': 1,
#   'pick': 5,
#   'theirs.]': 1,
#   'Admiral': 2,
#   'report': 1,
#   'barge': 1,
#   'purr.]': 1,
#   'add': 2,
#   'sea': 2,
#   'move.': 4,
#   'elude': 1,
#   'victory,': 1,
#   'grant': 1,
#   'being': 2,
#   'struggle': 3,
#   'sweeps': 1,
#   'follow.]': 2,
#   'suck': 3,
#   'white,': 3,
#   'tree': 3,
#   'bed.': 1,
#   'cast': 1,
#   'spear': 2,
#   'smile': 5,
#   'bristle': 2,
#   'worry.': 1,
#   'rain.': 2,
#   'shelter': 1,
#   'predict': 2,
#   'foot': 1,
#   'fall.]': 1,
#   'observe': 3,
#   'stroll': 1,
#   'shake': 6,
#   'flinch.': 1,
#   'contain': 4,
#   'sample': 1,
#   'marry,': 1,
#   'have.': 1,
#   'eavesdrop': 1,
#   'marry.': 1,
#   'stop.]': 1,
#   'know!': 1,
#   'Aunt': 6,
#   'cheer': 2,
#   'allow': 2,
#   'bother': 4,
#   'marry': 2,
#   'outside': 34,
#   'toe.': 1,
#   'spit': 3,
#   'warn': 2,
#   'walk!': 1,
#   'convince': 2,
#   'believe': 5,
#   'us!': 1,
#   'reason.': 1,
#   'borrow': 2,
#   'snoop': 1,
#   'smooth': 1,
#   'immediately': 1,
#   'completely': 1,
#   'shape': 3,
#   'dig': 2,
#   'Poi': 1,
#   'evacuate!': 1,
#   'overflow': 1,
#   'rain': 1,
#   'airbend.': 1,
#   'overflow,': 1,
#   'advance': 1,
#   'stone.': 1,
#   'hear.': 2,
#   "Meng's": 1,
#   'grass': 1,
#   'study': 2,
#   'present-day,': 1,
#   'attack.': 7,
#   'closer-up': 1,
#   'reflect': 2,
#   'flee;': 1,
#   'Nyla.]': 2,
#   'mount': 3,
#   'side-shot': 3,
#   'war,': 1,
#   'shiver.': 1,
#   'follow.': 1,
#   'moths': 1,
#   'Nyla.': 2,
#   'wait': 2,
#   'travel.': 2,
#   'footprints': 1,
#   'frustration': 1,
#   'enjoy': 1,
#   "Bato's": 2,
#   'Bato.': 1,
#   'shore.': 1,
#   'ice': 3,
#   'lee.': 1,
#   'lee!': 1,
#   'Bato': 2,
#   'these': 1,
#   "Nyla's": 1,
#   'paralyze': 2,
#   'Nyla': 5,
#   'June': 4,
#   'dodge': 8,
#   'remind': 3,
#   'lay': 3,
#   'at': 1,
#   'attack.]': 2,
#   'ourselves.': 1,
#   'upstage': 1,
#   'Chey,': 1,
#   'Chey': 1,
#   'gesture.]': 1,
#   'train': 3,
#   'pout,': 1,
#   'Jeong': 5,
#   'listen?': 1,
#   'illuminate': 1,
#   'concentrate': 3,
#   'innocent.': 1,
#   'breathe?': 1,
#   'breathe,': 1,
#   'stop!': 2,
#   'squat': 1,
#   'gesture': 1,
#   'bear.': 1,
#   'consume': 1,
#   'firebend': 7,
#   'eventually.': 1,
#   'sound': 3,
#   'sit': 6,
#   'stream': 1,
#   "Teo's": 1,
#   'machines.]': 1,
#   'stink.': 1,
#   'exterior': 4,
#   'rebuild': 1,
#   'come.]': 1,
#   'time,': 1,
#   'find.': 2,
#   'happen.': 3,
#   'locate': 2,
#   'explain.]': 1,
#   'remember': 6,
#   'spare': 1,
#   'offer.': 1,
#   'float.': 1,
#   'rubble!': 1,
#   'Fire': 7,
#   'more': 2,
#   'gliders': 1,
#   'tanks': 3,
#   'distance': 1,
#   'interiors': 1,
#   'one?': 1,
#   'aerial': 19,
#   'ground': 9,
#   'above': 4,
#   'scale': 1,
#   'Earth': 3,
#   'wide': 10,
#   'chains': 1,
#   'balcony': 1,
#   'panning': 8,
#   'snowy': 1,
#   'Qin,': 1,
#   'many': 3,
#   'complain,': 1,
#   'break,': 1,
#   "everyone's": 1,
#   'transport': 2,
#   'spectate': 1,
#   'Pakku.': 2,
#   'relax,': 1,
#   'heal.': 1,
#   'heal,': 1,
#   'fight!': 1,
#   'wish': 1,
#   'those': 3,
#   'her.]': 16,
#   'win': 9,
#   'slap': 1,
#   'direct': 3,
#   'hitting': 1,
#   'liquefy': 2,
#   'freeze': 4,
#   'struggle,': 2,
#   'stow': 1,
#   'know,': 2,
#   'launch': 9,
#   'under': 1,
#   'spar': 1,
#   'freeze,': 1,
#   'step': 2,
#   'Pakku': 6,
#   'surprise.': 1,
#   'lick': 3,
#   'lean': 3,
#   'civilians': 1,
#   'drag': 3,
#   'like': 4,
#   'vanish': 2,
#   'Hahn.]': 1,
#   'need': 3,
#   "bird's-eyes": 1,
#   'fireball': 1,
#   'back-flip': 1,
#   'long': 1,
#   'wrap': 2,
#   'rumble.': 1,
#   'dozens': 1,
#   'suspend': 1,
#   'determine': 4,
#   'Hahn.': 1,
#   'sunset': 1,
#   'comfort': 9,
#   'nightfall': 4,
#   'what': 6,
#   'paddle': 1,
#   'them!': 1,
#   'meditate.]': 1,
#   'warm': 2,
#   'steady': 5,
#   'scrub': 1,
#   'guard': 1,
#   'resurface,': 1,
#   'image': 1,
#   'slip': 4,
#   'rush': 1,
#   'resist': 1,
#   'realize': 1,
#   'full': 2,
#   'disturb': 1,
#   'confirm': 2,
#   'zoomed': 3,
#   'splinter': 1,
#   'remember.': 2,
#   'slay': 1,
#   'kill': 10,
#   "Ummi's": 1,
#   'Koh,': 2,
#   "Roku's": 7,
#   'waterbenders': 3,
#   'baboon': 1,
#   'cave': 2,
#   'escape.': 10,
#   'untie': 2,
#   'Tui': 1,
#   'waterbend': 5,
#   'Yue': 3,
#   'heal': 6,
#   'die.': 1,
#   'Arnook': 2,
#   'cry,': 1,
#   'Zhao.]': 1,
#   'discover': 6,
#   'any': 3,
#   'accept': 4,
#   'kiss': 4,
#   'calling': 1,
#   'glare': 3,
#   'daybreak.': 1,
#   'Gran-Gran': 1,
#   'pluck': 1,
#   'Azula.': 5,
#   'Fong,': 2,
#   'wield': 1,
#   'summon': 2,
#   "Azula's": 4,
#   'twitch': 1,
#   'death.': 1,
#   'sneeze,': 1,
#   'come.': 3,
#   'overthrow': 4,
#   'call': 4,
#   'ponder': 2,
#   'overall': 1,
#   'yourself.': 1,
#   'exit.]': 2,
#   'regret': 1,
#   'Azula?': 1,
#   'trigger': 2,
#   'bits.': 1,
#   'aid': 3,
#   'crush': 2,
#   'narrowly': 2,
#   'depart,': 1,
#   'Azula': 19,
#   'fury.': 1,
#   'Azula,': 12,
#   'force': 5,
#   'Fong.': 1,
#   'mud.': 1,
#   'acutely': 1,
#   'lock': 2,
#   'Azula.]': 6,
#   'scrape': 2,
#   'duel,': 1,
#   "Fong's": 1,
#   'spread.': 1,
#   "bird's-eye": 1,
#   'Roku.]': 3,
#   'empower': 1,
#   'fade': 1,
#   'exist.': 1,
#   'Omashu?': 1,
#   'cower': 1,
#   'hide!': 1,
#   'riverbank': 2,
#   'Omashu': 5,
#   'nomads.': 1,
#   'eat!': 1,
#   'cure': 2,
#   'point': 1,
#   'solve': 2,
#   'touch': 2,
#   'scratch': 1,
#   'nighttime': 2,
#   'panic.': 2,
#   'charge.': 1,
#   'this:': 1,
#   'side.': 5,
#   'depart': 1,
#   'below': 1,
#   'clear': 5,
#   'maneuver': 1,
#   'wash': 2,
#   'dry': 2,
#   'slience': 1,
#   "Mai's": 4,
#   'them.\nKatara': 1,
#   'collapse.': 2,
#   'bow': 3,
#   'embrace': 1,
#   'Ty': 14,
#   'Omashu,': 1,
#   'freedom.': 2,
#   'retreat,': 1,
#   'retreat': 1,
#   'alert': 1,
#   'spread': 3,
#   'drool.': 1,
#   'Tom-Tom': 1,
#   'screech': 1,
#   'set': 4,
#   'greet': 3,
#   'Yung.]': 1,
#   'cry.': 3,
#   'Yung': 1,
#   'Yung.': 1,
#   'Mai.': 3,
#   'laugh.': 2,
#   'trade.': 1,
#   'freeze.\nOn': 1,
#   'prevent': 3,
#   'crash': 4,
#   'peddle': 1,
#   'manage!': 1,
#   'earthbending.': 1,
#   'understand.]': 2,
#   'drive': 4,
#   'Mai.]': 4,
#   'sing.]': 3,
#   'Ba': 25,
#   '"dodge"': 1,
#   'tears.]': 2,
#   'ignore': 1,
#   'me?!': 1,
#   'attempt': 1,
#   'squash': 1,
#   'chop': 1,
#   'stop,': 2,
#   'perk': 1,
#   'widen.': 1,
#   'wind': 1,
#   'indicate': 3,
#   "folla'.": 1,
#   'lighten.': 1,
#   'appease': 1,
#   'investigate': 4,
#   'patch': 1,
#   'belong': 2,
#   'regenerate.': 1,
#   'land.': 1,
#   'us': 3,
#   'Huu,': 1,
#   'distinguish': 1,
#   'Huu.]': 2,
#   'hurry!': 1,
#   ...},
#  'tell': {'me': 32,
#   'you,': 6,
#   'us!': 1,
#   'by': 2,
#   'us': 11,
#   'him.': 2,
#   'Aang': 1,
#   'us,': 1,
#   'me,': 2,
#   'you': 24,
#   'ya': 1,
#   'from': 1,
#   'the': 7,
#   'your': 3,
#   'you?': 2,
#   'you.': 2,
#   'us.': 1,
#   'everything': 1,
#   'stories': 1,
#   'their': 1,
#   'you:': 1,
#   "'em": 1,
#   'me.': 3,
#   'her': 3,
#   'him': 2,
#   'before': 1,
#   'me-': 1,
#   'where': 1,
#   'them': 1,
#   'them!': 1,
#   "you're": 1,
#   "who's": 1,
#   'me-\xa0!': 1,
#   'ourselves.': 1,
#   'Father': 1,
#   'those': 1,
#   'me!': 1,
#   'us?': 1,
#   'if': 1,
#   'anyone!': 1,
#   'my': 1,
#   'bad': 1},
#  'me': {'stories': 1,
#   'and': 19,
#   'this': 5,
#   'weird?': 1,
#   'tell': 3,
#   'like': 10,
#   'Gran-Gran.': 1,
#   'control': 1,
#   'the': 9,
#   'waterbending.': 1,
#   'catch': 1,
#   'to': 46,
#   'until': 1,
#   'out': 8,
#   'with': 9,
#   'for': 6,
#   'what': 10,
#   'in': 14,
#   'everything': 4,
#   'home': 1,
#   'humiliate': 1,
#   'if': 4,
#   'that': 10,
#   'being': 1,
#   'up': 2,
#   'better': 1,
#   'carry': 1,
#   'explain.': 2,
#   'yesterday?': 1,
#   'worried.': 1,
#   'forever!': 1,
#   'who': 2,
#   'tired.': 1,
#   'my': 1,
#   'from': 1,
#   'confused': 1,
#   'not': 1,
#   'of': 3,
#   'right': 2,
#   'pipsqueak,': 1,
#   'as': 5,
#   'asking,': 1,
#   'exactly': 1,
#   'some': 8,
#   'find': 4,
#   'sick!': 1,
#   'how': 5,
#   'up?': 1,
#   'up.': 1,
#   'either.': 1,
#   'about?': 1,
#   'well.': 1,
#   'hope': 1,
#   'again,': 1,
#   'ten': 1,
#   'next.': 1,
#   'months': 1,
#   'two': 1,
#   'a': 12,
#   'here!': 1,
#   'where': 7,
#   'get': 2,
#   'out?': 2,
#   'we': 3,
#   'forever.': 1,
#   'go': 1,
#   'you': 7,
#   'back': 1,
#   'Katara.': 1,
#   'guess,': 2,
#   'something': 1,
#   'ahead': 1,
#   'wrong,': 2,
#   'twice.': 1,
#   'about': 8,
#   'I': 3,
#   'in!': 2,
#   'pass!': 1,
#   'more!': 2,
#   'all': 3,
#   'in?': 1,
#   'she': 2,
#   'see': 5,
#   'ever': 1,
#   'great': 1,
#   'along.': 1,
#   'back!': 1,
#   'behind.': 1,
#   'gone.': 1,
#   'when': 2,
#   'help': 2,
#   'an': 1,
#   'three': 1,
#   'waiting.': 1,
#   'close': 1,
#   'capture': 1,
#   'your': 3,
#   'no!': 1,
#   'whatever': 1,
#   'down!': 1,
#   '...': 8,
#   'strong.': 1,
#   'Zuko,': 1,
#   'Yue.': 1,
#   'killed!': 1,
#   'life,': 1,
#   'that!': 2,
#   'back?': 1,
#   'that.': 1,
#   'too!': 1,
#   "you're": 3,
#   'pleasure': 1,
#   'out!': 3,
#   'interrupt': 1,
#   'on': 4,
#   'strong': 1,
#   'in.': 3,
#   'earthbending.': 1,
#   'here': 1,
#   'or': 1,
#   "I've": 1,
#   'without': 2,
#   'realize': 2,
#   'buy': 1,
#   'alone.': 2,
#   'handle': 1,
#   'secret': 1,
#   'stuff': 1,
#   'pour': 1,
#   'around': 1,
#   'Sifu': 1,
#   'first?': 1,
#   'these': 1,
#   'is': 1,
#   'confused.': 1,
#   'out,': 1,
#   'again.': 1,
#   'do': 1,
#   'know': 1,
#   'put': 3,
#   'drown': 1,
#   'plug': 1,
#   'go!': 1,
#   'any': 1,
#   'Sokka,': 1,
#   'something?': 1,
#   '–': 1,
#   'nauseous.': 1,
#   'anymore.': 1,
#   'enough': 1,
#   'really': 1,
#   'more': 2,
#   'take': 2,
#   'down': 1,
#   'at': 6,
#   'guess.': 2,
#   'through!': 1,
#   'master': 1,
#   'just': 3,
#   'back.': 2,
#   'anything?': 1,
#   'too,': 1,
#   'everything.': 1,
#   'dancing': 1,
#   'check': 1,
#   'too.': 2,
#   'one': 2,
#   'too': 1,
#   'alone!': 1,
#   'out.': 3,
#   'this?': 1,
#   'while': 1,
#   'crazy!': 1,
#   'use': 1,
#   'that?': 1,
#   'into': 2,
#   "what's": 1,
#   'next': 1,
#   'start': 1,
#   'he': 1,
#   'gone,': 1,
#   'here.': 2,
#   'chained': 1,
#   'now!': 3,
#   'plenty': 1,
#   'alone,': 1,
#   'feel': 3,
#   'over': 1,
#   "it's": 1,
#   'tearbend!': 2,
#   'look': 1,
#   'so': 3,
#   'fire': 1,
#   'backstage?': 1,
#   'hear': 1,
#   'Pakku.': 1,
#   "I'm": 1,
#   'think.': 1,
#   'why,': 1,
#   'anymore?': 1,
#   'again!': 1,
#   'was': 1,
#   'something.': 1,
#   "Momo's": 1,
#   'firebending?': 1},
#  'stories': {'about': 3,
#   'of': 2,
#   'for': 1,
#   'and': 2,
#   'from': 1,
#   'the': 1,
#   'this': 1,
#   'like': 1,
#   '...': 1},
#  'about': {'the': 54,
#   'to': 56,
#   'it,': 2,
#   'it.': 14,
#   'it': 5,
#   'booby': 1,
#   'this': 10,
#   'in': 6,
#   "'em?": 1,
#   'is': 2,
#   'being': 4,
#   'yesterday.': 1,
#   'strength.': 1,
#   'using': 1,
#   'this?': 2,
#   'a': 10,
#   'you?': 4,
#   'what': 10,
#   'your': 14,
#   'employing': 1,
#   'that.': 10,
#   'all': 2,
#   'that': 3,
#   'Momo?': 1,
#   'me?': 7,
#   'it:': 1,
#   'wildly.]': 1,
#   'how': 8,
#   'from': 1,
#   'as': 1,
#   'gathering': 1,
#   'stealing': 2,
#   'our': 8,
#   'it?': 5,
#   'my': 9,
#   'respect?': 1,
#   'respect!': 1,
#   'anyone': 1,
#   'Zuko': 1,
#   'it!': 2,
#   'Appa': 3,
#   'back': 1,
#   'love?': 2,
#   'ladies,': 1,
#   'you.': 9,
#   'her': 3,
#   'not': 2,
#   'an': 1,
#   'that?': 2,
#   'trust.': 2,
#   'two': 3,
#   'you,': 5,
#   'going': 1,
#   'you!': 3,
#   'air': 1,
#   'sinking': 1,
#   'Prince': 1,
#   'on': 2,
#   'some': 4,
#   'wildly,': 1,
#   'Aang?': 2,
#   'attacking': 1,
#   'smashing': 1,
#   'killing': 1,
#   'me,': 1,
#   'something?': 1,
#   'me!': 1,
#   'me.': 4,
#   'him.': 2,
#   'cautiously.]': 1,
#   'through': 1,
#   'where': 1,
#   'helplessly': 1,
#   'their': 3,
#   'and': 2,
#   'each': 1,
#   'hopelessly,': 1,
#   'Sokka?': 1,
#   'Aang.]': 1,
#   'finding': 2,
#   'this.': 7,
#   'this,': 1,
#   'when': 1,
#   'The': 1,
#   'fighting': 1,
#   'dinner.': 1,
#   'things': 1,
#   'setting': 2,
#   'him': 3,
#   'Lu': 1,
#   'five': 1,
#   "what's": 1,
#   'eclipses': 1,
#   'Appa.': 1,
#   'losing': 2,
#   'was': 2,
#   'giant': 1,
#   'last': 1,
#   'those': 1,
#   'him,': 1,
#   'sick': 1,
#   '...': 2,
#   'month.': 1,
#   'them!': 1,
#   'time': 1,
#   'appearance.': 1,
#   'working': 1,
#   'Appa?': 1,
#   'names': 1,
#   'conquering': 1,
#   'chakras.': 1,
#   'make-up': 1,
#   'me': 2,
#   'you': 4,
#   'expressing': 1,
#   'them.': 3,
#   '"taking': 1,
#   'these?': 1,
#   'putting': 1,
#   'anything,': 1,
#   'bad': 1,
#   'ourselves.': 1,
#   "Sozin's": 1,
#   'friendships.': 1,
#   'getting': 3,
#   'halfway.': 1,
#   'everything': 1,
#   'anymore.': 1,
#   'living': 1,
#   'had': 1,
#   'her!': 1,
#   'space.': 1,
#   'everything,': 1,
#   'ten': 1,
#   'by': 1,
#   'his': 1,
#   'fighting.': 1,
#   'architecture.': 1,
#   'firebending': 1,
#   'fire': 1,
#   'war': 1,
#   'controlling': 1,
#   'uncontrollably.]': 1,
#   'us.': 1,
#   'ourselves?': 1,
#   'meat': 1,
#   'plenty': 1,
#   'hope': 1,
#   'for': 1,
#   'Grand-Pakku?': 1,
#   'philosophy': 1,
#   'anything': 1,
#   'seeing': 1,
#   'us?': 1,
#   'Aang.': 1,
#   'her;': 1,
#   'King': 1},
#  'the': {'old': 22,
#   'Avatar': 177,
#   'Water': 36,
#   'Fire': 388,
#   'ruthless': 1,
#   'world': 34,
#   'war.': 5,
#   'men': 10,
#   'Earth': 111,
#   'Air': 10,
#   'cycle': 1,
#   'world.': 42,
#   'title': 1,
#   'scene': 79,
#   'left,': 19,
#   'water': 159,
#   'shot': 39,
#   'untouched': 1,
#   'sea': 7,
#   'paleness': 1,
#   'sky': 39,
#   'left': 39,
#   'wake': 1,
#   'canoe': 9,
#   'walls': 13,
#   'vessel.': 2,
#   'boat;': 1,
#   'boy': 25,
#   'ready,': 3,
#   'girl': 18,
#   'other': 203,
#   'boat.': 11,
#   'surface': 22,
#   'boy,': 6,
#   'direction': 24,
#   'girl.]': 2,
#   'boat': 24,
#   'glove': 1,
#   'fish,': 4,
#   'fish': 11,
#   'shot,': 5,
#   'ocean': 16,
#   'newly': 2,
#   'fish.]': 2,
#   'bubble': 3,
#   'air': 127,
#   'focus': 1,
#   'water.': 71,
#   'blunt': 3,
#   'water;': 4,
#   'sea.': 2,
#   'rim': 17,
#   'one': 34,
#   'water!': 5,
#   'end': 27,
#   'canoe,': 2,
#   'narrow': 1,
#   'towering': 2,
#   'ice': 22,
#   'boat,': 5,
#   'icebergs,': 1,
#   'right': 83,
#   'current': 2,
#   'ice,': 5,
#   'floes;': 1,
#   'water,': 54,
#   "floe's": 1,
#   'siblings': 9,
#   'middle': 53,
#   'floe,': 1,
#   'ice.': 10,
#   'two': 179,
#   'large': 18,
#   'siblings.': 5,
#   'pointed': 1,
#   'siblings;': 2,
#   'floe': 2,
#   'most': 21,
#   'movement': 3,
#   'iceberg;': 4,
#   'iceberg': 16,
#   'work': 1,
#   'last': 61,
#   'crack': 2,
#   'iceberg.': 6,
#   'clothes!': 1,
#   'chunk': 2,
#   'top': 97,
#   'iceberg,': 4,
#   'widening': 1,
#   "siblings'": 1,
#   'waves': 3,
#   'siblings,': 3,
#   'edge': 58,
#   'spread': 1,
#   'brilliant': 2,
#   'bubbles': 2,
#   'head-on': 1,
#   'edge,': 5,
#   'water.\nThe': 3,
#   'surface,': 6,
#   'source': 9,
#   'glow.': 1,
#   "iceberg's": 1,
#   'berg': 1,
#   'object;': 1,
#   'figure': 5,
#   'same': 97,
#   'strange': 7,
#   "ice's": 1,
#   'short': 1,
#   'same.': 11,
#   'club': 5,
#   'side': 101,
#   'dome.': 1,
#   'whole': 44,
#   'entire': 72,
#   'core': 1,
#   'sky.': 40,
#   'shallow': 1,
#   'distant': 2,
#   'deck,': 12,
#   'light.': 5,
#   'wind.': 11,
#   'tile': 3,
#   'light.]': 2,
#   'table.': 16,
#   'light': 19,
#   'celestial': 1,
#   'symbol': 6,
#   'open': 15,
#   'table': 25,
#   'Avatar!': 20,
#   'light!': 1,
#   'airbending': 4,
#   'previous': 5,
#   'gale': 1,
#   'remains': 4,
#   'former': 9,
#   'crater,': 5,
#   'depression': 1,
#   'ground': 212,
#   "boy's": 5,
#   'spear': 9,
#   'base': 33,
#   'crater.': 3,
#   'Southern': 38,
#   'threesome': 3,
#   'crater.]': 1,
#   'ice?': 1,
#   'air,': 34,
#   'crater': 5,
#   'ridge': 2,
#   'head': 20,
#   'boy.': 6,
#   'beast': 4,
#   'front': 43,
#   'bison': 19,
#   'corner': 16,
#   'beast.': 4,
#   "bison's": 8,
#   'creature': 13,
#   'picture': 10,
#   'snow': 17,
#   'amused': 1,
#   'thing.]': 1,
#   'air.': 55,
#   'ground,': 88,
#   'sky.]': 13,
#   'air!': 3,
#   'bison.]': 5,
#   'help': 5,
#   'reins': 9,
#   'saddle': 15,
#   'icy': 13,
#   'helm': 1,
#   'distance.': 28,
#   "Avatar's": 21,
#   'Avatar?': 14,
#   'vast': 3,
#   'rumble': 1,
#   'following': 2,
#   'next': 43,
#   'reigns': 3,
#   'waters': 2,
#   'ocean.': 20,
#   'dream.': 2,
#   'covers': 3,
#   'village': 34,
#   'door': 87,
#   'tent.]': 7,
#   'door.': 42,
#   'blue,': 1,
#   'rest': 78,
#   'village.\nAang': 1,
#   'tent': 9,
#   'tent,': 7,
#   'line': 13,
#   'villages,': 1,
#   'sudden': 5,
#   'gazing': 1,
#   'villagers,': 5,
#   "village's": 2,
#   'tower': 6,
#   'building.': 12,
#   'damage': 6,
#   'partially': 1,
#   'tribe': 2,
#   'snow.]': 2,
#   'hope': 1,
#   'weight': 4,
#   'duo': 11,
#   'real': 19,
#   'smaller': 2,
#   'uniforms': 1,
#   'fight': 10,
#   'firebender': 4,
#   'way.': 21,
#   'way': 68,
#   'breath': 1,
#   'breathing': 1,
#   'muscles.': 1,
#   'body.': 2,
#   'soldiers.': 8,
#   'fire': 38,
#   'attitude': 2,
#   'four': 24,
#   'advanced': 1,
#   'ground.]': 31,
#   'roast': 1,
#   'dismay': 1,
#   'word': 3,
#   'people': 20,
#   'air.]': 20,
#   'War,': 6,
#   'children': 8,
#   'bathroom': 1,
#   'sound': 25,
#   'tail': 4,
#   'snow,': 7,
#   'War': 10,
#   'laughing': 2,
#   'expression': 3,
#   'penguin.': 2,
#   'otter-penguin': 1,
#   'penguins': 4,
#   'animal': 15,
#   'snow.': 8,
#   'animals': 4,
#   'only': 47,
#   'North': 32,
#   'second': 25,
#   'meantime,': 2,
#   'fish.': 5,
#   'slope': 9,
#   'lead': 10,
#   'ceiling': 26,
#   'bow': 14,
#   'wreckage.]': 1,
#   'ship.': 31,
#   'blocks': 1,
#   'ship': 46,
#   'hull': 4,
#   'silent': 1,
#   'shipwreck.': 1,
#   'otherwise': 1,
#   'room.]': 10,
#   'room,': 32,
#   'weapons': 4,
#   'world,': 14,
#   'room.': 43,
#   'entrance,': 2,
#   'bars': 6,
#   'shipwreck': 1,
#   'movements': 1,
#   'machines': 1,
#   'roof': 25,
#   'power': 10,
#   'hole.\nThe': 1,
#   'Avatar.': 67,
#   'Avatar,': 24,
#   'new': 20,
#   'yellowing': 1,
#   'flare': 1,
#   'figures': 2,
#   'horizon.': 9,
#   "duo's": 1,
#   'gathered': 1,
#   'others': 24,
#   'crowd.': 9,
#   'adults,': 1,
#   'enemy.': 2,
#   'airbender': 4,
#   'South': 10,
#   'airbenders.': 3,
#   'reins,': 6,
#   'wind.]': 4,
#   'hill.': 6,
#   'village,': 15,
#   'young': 16,
#   'village.': 18,
#   'right,': 12,
#   'lower': 8,
#   'camera': 222,
#   'low-stooping': 1,
#   'town.': 16,
#   'wall,': 30,
#   'foggy': 1,
#   'surrounding': 9,
#   'noise': 5,
#   'wall': 72,
#   'pressure': 1,
#   'trembling,': 1,
#   "tower's": 1,
#   'citizens': 3,
#   'scene.': 13,
#   'vessel': 2,
#   'shadow': 2,
#   "ship's": 5,
#   'snowy': 2,
#   'ground.': 126,
#   'wall.': 36,
#   'child': 3,
#   'way!': 2,
#   'shape': 7,
#   'mist.\nCut': 1,
#   'walkway,': 3,
#   'mist,': 2,
#   'villagers': 16,
#   'walkway': 2,
#   'prince': 7,
#   'ready.': 4,
#   'crowd': 25,
#   'hood': 2,
#   'heads': 6,
#   'people,': 4,
#   'prince.': 4,
#   'camera.': 48,
#   'warrior': 3,
#   'enemy': 2,
#   'weapon.': 2,
#   'near': 1,
#   'course': 2,
#   'weapon': 8,
#   'pieces': 3,
#   'distance': 9,
#   'back': 62,
#   'unexpected': 2,
#   'battle': 7,
#   'children,': 2,
#   'penguin': 1,
#   'present': 8,
#   'impact.': 6,
#   'airbender?': 1,
#   'attack': 16,
#   'other.': 9,
#   'remark,': 1,
#   'flames.': 10,
#   'area,': 4,
#   'flames': 17,
#   'sight': 12,
#   'frightened': 4,
#   'walkway.': 4,
#   'ship,': 26,
#   'day;': 1,
#   'wreckage': 1,
#   'collapsed': 3,
#   'background,': 28,
#   'screen.]': 1,
#   'sleeping': 6,
#   "world's": 3,
#   'ready': 3,
#   'staff': 10,
#   'prison': 22,
#   'staff;': 1,
#   'soldiers': 27,
#   'upper': 13,
#   'deck.': 9,
#   'staircase,': 1,
#   'outside': 11,
#   'cuffed': 1,
#   'soldier': 8,
#   'guard': 33,
#   'cell,': 4,
#   'stairs.': 9,
#   'impact,': 2,
#   'deck': 19,
#   'hallway,': 2,
#   'helmsman': 1,
#   'screen.\nThe': 1,
#   'seas': 2,
#   'saddle.': 20,
#   'saddle.]': 9,
#   'sky.\nThe': 1,
#   'corridors.': 1,
#   'corridor.': 2,
#   'hallway': 10,
#   'speed': 4,
#   'floor': 38,
#   'walls,': 2,
#   'soldiers,': 3,
#   'hallways': 1,
#   'sharp': 2,
#   'impact': 13,
#   'hall.': 6,
#   'interior,': 2,
#   'third': 10,
#   'door,': 29,
#   'crack.': 1,
#   'interior': 6,
#   'entranceway': 2,
#   'doorway': 10,
#   'object,': 1,
#   'closing': 3,
#   'attack.': 20,
#   'window': 22,
#   'room': 53,
#   'tapestry': 3,
#   'top,': 6,
#   'mattress.': 1,
#   'mattress': 4,
#   'floor,': 17,
#   'empty': 5,
#   'main': 26,
#   'hatch': 3,
#   'control': 3,
#   'helm.': 1,
#   'man': 35,
#   'fresh': 1,
#   'balcony': 12,
#   'extra,': 1,
#   'ledge': 13,
#   'side,': 18,
#   'object': 6,
#   'very': 9,
#   'waterspout.': 1,
#   'vortex.': 1,
#   'unconscious': 3,
#   'glory.': 2,
#   'glider': 5,
#   'staff.': 1,
#   'anchor': 1,
#   'puddle,': 1,
#   'process.': 14,
#   'ice.]': 2,
#   'cabin': 1,
#   'bison.': 5,
#   'incoming': 2,
#   'small': 9,
#   'fireball': 3,
#   'event,': 1,
#   'trio,': 5,
#   'cliff.\nSwitch': 1,
#   'background.': 37,
#   'damaged': 1,
#   'piles': 1,
#   'three': 48,
#   'clouds.': 12,
#   'sun': 24,
#   'saddle,': 10,
#   'water?': 2,
#   'sky,': 10,
#   'monks': 13,
#   'scroll,': 5,
#   'locations.]': 1,
#   'location': 5,
#   'hopping': 1,
#   'backs': 2,
#   'hog': 2,
#   'clouds': 13,
#   'morning': 3,
#   'group': 90,
#   'shore.': 12,
#   'smoke': 11,
#   'nearby': 7,
#   'fire.': 19,
#   'knots': 1,
#   'world!': 9,
#   'approaching': 9,
#   'stick': 2,
#   'tip': 7,
#   'others,': 3,
#   'bottom': 24,
#   'repairs': 1,
#   'severely': 1,
#   'thrilling': 1,
#   'Patola': 2,
#   'luggage': 2,
#   'bag': 21,
#   'contents': 6,
#   'campfire': 4,
#   'temple,': 14,
#   'mountain': 14,
#   'flank': 1,
#   'rocks': 17,
#   'temple.': 16,
#   'shipyard.': 1,
#   'ships.': 3,
#   'bigger': 2,
#   "year's": 1,
#   'corner,': 5,
#   'screen': 18,
#   'guards': 32,
#   'crew': 8,
#   'front,': 7,
#   'screen.': 19,
#   'first': 48,
#   'trio': 30,
#   'deserted': 2,
#   'ledge;': 1,
#   'wind,': 1,
#   'corners': 2,
#   'goal': 4,
#   'airball': 2,
#   'court,': 1,
#   'tall': 4,
#   'ball': 28,
#   'upward': 1,
#   'poles,': 2,
#   'stomach.': 2,
#   'rotating': 1,
#   'goal.': 2,
#   'dirt.': 2,
#   'background': 23,
#   'front.': 8,
#   'elements,': 3,
#   'hollow': 1,
#   'truth': 6,
#   'helmet': 2,
#   'overhanging': 2,
#   "temple's": 3,
#   'middle.': 8,
#   'entrance': 22,
#   'courtyard,': 8,
#   'shoulder': 9,
#   'statue.': 17,
#   'statue': 31,
#   'statue.]': 5,
#   "statue's": 5,
#   'face': 17,
#   'true': 3,
#   'gooey': 1,
#   'use': 5,
#   'oven.': 1,
#   'fruity': 1,
#   'pie.\nThe': 1,
#   'balcony,': 7,
#   'trees': 5,
#   'beauty': 2,
#   'background.]': 18,
#   'ledge,': 1,
#   'close': 1,
#   'flying': 11,
#   'cakes': 1,
#   'colorful': 1,
#   'far': 4,
#   'pies': 1,
#   'lemurs': 2,
#   'stomach': 5,
#   'toppled-over': 1,
#   'monk': 4,
#   'monks.': 2,
#   'railing': 10,
#   'balcony.': 3,
#   'present,': 4,
#   'hallway.': 5,
#   'national': 1,
#   'branches': 1,
#   'thought.]': 1,
#   'giant': 15,
#   'tubes': 1,
#   'path': 13,
#   'pipe.': 1,
#   'blue': 18,
#   'tube': 2,
#   'wind': 11,
#   'sanctuary,': 1,
#   'dark': 16,
#   'sanctuary.]': 1,
#   'sanctuary': 2,
#   'darkness.\nThe': 1,
#   'commander,': 1,
#   'objects': 4,
#   'sanctuary.': 6,
#   'floor.': 19,
#   'statues': 7,
#   'meat?': 1,
#   'right.': 10,
#   'airbender.]': 1,
#   'left.]': 5,
#   'respective': 1,
#   'circular': 3,
#   'reveal': 1,
#   'cycle.': 1,
#   'elderly': 6,
#   'duo,': 2,
#   'statues,': 2,
#   'threesome.': 3,
#   'huddled': 1,
#   'bases': 1,
#   'doorway;': 2,
#   'figure.': 3,
#   'statue,': 4,
#   'animal.': 4,
#   'erect': 1,
#   'appeared': 1,
#   'lemur,': 2,
#   'lemur': 10,
#   'boys.': 1,
#   'snatching': 1,
#   'boys': 7,
#   'lemur.': 4,
#   'lead.': 3,
#   'corridor': 3,
#   'rim.': 2,
#   'occupied': 2,
#   'exit.': 4,
#   'cloths': 1,
#   'throne!': 2,
#   'scar': 4,
#   'temple': 22,
#   "animal's": 3,
#   'lemur.]': 3,
#   'decaying': 2,
#   'curtain': 4,
#   'skeleton': 3,
#   'skeletons.': 1,
#   'round,': 1,
#   'skeleton;': 1,
#   'drapes': 1,
#   'monk,': 1,
#   'mountains.': 5,
#   'typical': 2,
#   "man's": 9,
#   'recipient': 1,
#   'raging': 2,
#   'dilapidated': 1,
#   'force': 6,
#   'hurricane': 1,
#   'rubble': 4,
#   'building': 17,
#   'winds': 2,
#   'rock': 45,
#   'mountain!': 1,
#   'storm': 4,
#   'strong': 1,
#   'sphere': 1,
#   'inside.': 8,
#   'arena.': 12,
#   'arena': 11,
#   'arena,': 6,
#   'right.\nCut': 1,
#   'blast': 15,
#   'background;': 3,
#   'blasts': 2,
#   'prince,': 1,
#   'skies': 4,
#   'final': 15,
#   'commander': 1,
#   'great': 13,
#   'floor.]': 3,
#   'tea.': 3,
#   'gate': 8,
#   'duo.': 4,
#   'harbor': 2,
#   'destroyed': 6,
#   'storm.': 3,
#   'ground;': 11,
#   'glowing': 2,
#   'firebenders': 9,
#   'doorway.': 9,
#   'load': 1,
#   'fruit,': 1,
#   'food': 11,
#   'winged-lemur.]': 1,
#   'newest': 1,
#   'duo.]': 1,
#   'peach': 1,
#   'peach.': 1,
#   'entirety': 1,
#   "prince's": 1,
#   'candles': 6,
#   'flames,': 4,
#   'scroll': 22,
#   'map!': 1,
#   'parchment.]': 3,
#   'map': 18,
#   "team's": 5,
#   'zigzagged': 1,
#   'trick.]': 1,
#   'natural': 3,
#   'pants': 2,
#   'pair': 2,
#   'face,': 3,
#   'shore,': 7,
#   'bay.': 1,
#   'beach,': 1,
#   'coastline': 1,
#   'deep': 1,
#   'bay': 3,
#   'koi': 12,
#   "fish's": 1,
#   'koi.': 1,
#   'beach.': 10,
#   'water.]': 21,
#   'work.': 5,
#   'shore': 8,
#   'smile': 1,
#   'bottom-right': 1,
#   'screen,': 7,
#   "water's": 4,
#   'danger.': 2,
#   'dorsal': 3,
#   'commotion': 4,
#   'lake,': 5,
#   'massive': 4,
#   'unknown': 2,
#   'sight.': 7,
#   'lake': 5,
#   'scene,': 5,
#   'surface.': 4,
#   'two.': 14,
#   'road.': 3,
#   'treetops': 2,
#   'trio.': 5,
#   'opportunity': 5,
#   'female': 9,
#   'beginning': 9,
#   'left.': 7,
#   'woman': 9,
#   'blindfolded': 1,
#   'forearm': 1,
#   'blindfold.': 2,
#   'elephant': 2,
#   'bound': 2,
#   'war': 28,
#   'wooden': 11,
#   'group.': 19,
#   'red': 12,
#   'modern': 1,
#   'impostor': 1,
#   'ropes,': 1,
#   'pole.': 1,
#   'outstretched': 1,
#   'surprised': 5,
#   'Kyoshi': 22,
#   'marbles': 1,
#   'crowd,': 7,
#   'cheering': 4,
#   'camera,': 17,
#   'news?': 1,
#   'fisherman': 7,
#   'basket': 6,
#   'fishmonger': 2,
#   'news': 3,
#   'news.': 3,
#   'servant': 3,
#   'cooked': 1,
#   'rhinos.': 1,
#   'smoking': 1,
#   'plate': 2,
#   'watchful': 3,
#   'street.': 10,
#   'big': 9,
#   'center': 25,
#   'the': 2,
#   'house': 15,
#   'already': 1,
#   'display': 1,
#   'squishy': 1,
#   'dessert': 4,
#   'deliciousness': 1,
#   'desserts': 1,
#   'orange': 3,
#   'theft': 1,
#   'piece': 4,
#   'hunched': 1,
#   'back.': 8,
#   'amount': 1,
#   'desert': 10,
#   'table.]': 7,
#   'deserts': 1,
#   'sweets': 1,
#   'looks': 5,
#   'royal': 7,
#   'pastry': 1,
#   'girls': 15,
#   'picture,': 1,
#   'bridge': 20,
#   'bridge,': 5,
#   'middle,': 5,
#   'artist': 1,
#   'outlines': 2,
#   'canvas': 2,
#   'annoyed': 3,
#   'painter.': 1,
#   'fangirls': 1,
#   'painting.': 1,
#   'Avatar.\nCut': 1,
#   'house,': 2,
#   'best': 14,
#   'position': 4,
#   'arm': 5,
#   'poke': 1,
#   'room?': 1,
#   'pot': 6,
#   'offered': 2,
#   'girls.': 4,
#   'latter': 16,
#   'heavy': 1,
#   'screen.\nScene': 1,
#   'dojo.': 2,
#   'dojo': 2,
#   'eight': 1,
#   'two;': 1,
#   'white': 6,
#   'brave': 2,
#   'honor': 3,
#   "warrior's": 3,
#   'embarrassed': 1,
#   'cup,': 1,
#   'rising': 2,
#   'plume': 1,
#   'bowl.': 1,
#   'fan': 4,
#   'hit': 2,
#   'momentum': 1,
#   'finger': 1,
#   'six': 1,
#   'girls.]': 2,
#   'shore.]': 2,
#   'danger': 2,
#   'monstrous': 1,
#   'meal.': 1,
#   'whisker': 1,
#   'throw.': 1,
#   'eel.': 1,
#   'rock.]': 3,
#   'fast': 2,
#   'banished': 4,
#   'body': 2,
#   'still': 4,
#   'riders': 4,
#   'support': 1,
#   'roof.': 7,
#   'town.]': 2,
#   'room.\nThe': 1,
#   'command,': 1,
#   'running': 3,
#   'riders.': 1,
#   'rider,': 1,
#   'background.\nCut': 1,
#   'downed': 3,
#   'fire,': 4,
#   'completely': 1,
#   'incoming,': 1,
#   'extra': 2,
#   'fans.': 2,
#   'burning': 8,
#   'house.': 14,
#   'firebender.': 2,
#   "bender's": 1,
#   'cheek,': 4,
#   'alleyway,': 1,
#   'reins.]': 2,
#   'ship!': 1,
#   'coast': 2,
#   'nearing': 1,
#   "creature's": 2,
#   'fires': 2,
#   'rain.': 3,
#   'rhinos,': 1,
#   'spectacle': 4,
#   'ocean,': 8,
#   'city': 33,
#   'city!': 4,
#   'hill': 11,
#   'wig.]': 1,
#   'frame,': 4,
#   'chasm,': 1,
#   'long': 7,
#   'city.': 35,
#   'gate.': 9,
#   'friendliest': 1,
#   'harsh': 1,
#   'sentry.': 1,
#   'closed': 1,
#   'talking': 1,
#   'cabbage': 8,
#   "merchant's": 2,
#   'cart,': 2,
#   'chasm': 1,
#   'cabbages.': 1,
#   'path.': 4,
#   'rim,': 4,
#   'guards,': 3,
#   'sentries': 1,
#   'boulder': 17,
#   'guard;': 1,
#   'chest': 7,
#   'sentry.]': 1,
#   'impact;': 1,
#   'camera.]': 12,
#   'guard,': 2,
#   'threateningly': 1,
#   'sentry': 1,
#   'Third,': 1,
#   "city's": 5,
#   'holdup': 1,
#   'emblem,': 2,
#   'opened': 1,
#   'parapet': 1,
#   'streets': 6,
#   'houses': 2,
#   'Omashu': 1,
#   'city.]': 2,
#   'cart': 21,
#   "cart's": 2,
#   'platform,': 3,
#   'packages': 1,
#   'trio;': 1,
#   'possibilities.': 3,
#   'start': 1,
#   'chutes.]': 1,
#   '"superslide",': 1,
#   'scene.\nSlowly,': 1,
#   'lush,': 2,
#   'slope,': 2,
#   'steepness': 1,
#   'chute.]': 1,
#   'balance': 2,
#   'box,': 2,
#   'hair,': 1,
#   'slope.': 2,
#   'spears': 2,
#   'spear-cart': 1,
#   'spears.': 1,
#   'chute': 6,
#   'warriors.': 1,
#   'track,': 3,
#   'supply': 1,
#   'speeding': 2,
#   'kids': 9,
#   'waiter': 1,
#   'arrival': 4,
#   'motionless': 1,
#   'bender.': 2,
#   "riders'": 1,
#   "kids'": 2,
#   'cart.': 3,
#   'vase': 2,
#   'ruined': 2,
#   'abyss': 1,
#   'replacement': 1,
#   'remains,': 1,
#   'palace': 13,
#   'King': 3,
#   'side.': 18,
#   'king,': 4,
#   '"visitors"': 1,
#   'merchant.]': 1,
#   'king': 23,
#   'dissimilar': 1,
#   'merchant': 2,
#   "king's": 2,
#   'food,': 1,
#   'table,': 4,
#   'chicken': 4,
#   'dining': 4,
#   'King,': 1,
#   'hay.': 2,
#   'meat': 5,
#   'airball.': 1,
#   'exit.]': 3,
#   'exit': 5,
#   'king.': 13,
#   'good': 7,
#   'bad': 3,
#   'guard.]': 6,
#   'recent': 1,
#   'refurbished': 1,
#   'content': 1,
#   'fact': 5,
#   'children.': 1,
#   'hole,': 3,
#   'bed,': 4,
#   'bed.': 1,
#   'tube.': 1,
#   'vent.': 1,
#   'earth': 23,
#   'guard.': 4,
#   'ensuing': 2,
#   'deadly': 1,
#   'surprise': 3,
#   'grasp': 1,
#   'ring': 15,
#   'waterfall,': 3,
#   'ladder': 2,
#   'waterfall.': 6,
#   'jennamite': 2,
#   ...},
#  'old': {'days:': 1,
#   'by': 1,
#   'age.': 1,
#   'Fire': 1,
#   'enough': 5,
#   'tree': 1,
#   'person.': 1,
#   "man's": 2,
#   'man': 24,
#   'timer!': 1,
#   'man.': 11,
#   'man,': 4,
#   'friends.': 3,
#   'friend': 3,
#   'man.]': 4,
#   'joints': 1,
#   'sometimes!': 1,
#   'man!': 5,
#   'falls,': 1,
#   'people': 2,
#   'people.': 3,
#   'folks': 1,
#   'general': 1,
#   'woman': 1,
#   "woman's": 1,
#   'enough.': 1,
#   'buddy!': 1,
#   'teacher': 1,
#   'master': 1,
#   'egg': 1,
#   'war': 1,
#   'friend,': 1,
#   'face': 1,
#   'story': 1,
#   'as': 1,
#   'fuddy-duddy': 1,
#   'for': 1,
#   'times,': 2,
#   'man?': 1,
#   'Slim?': 1,
#   'and': 3,
#   'abandoned': 1,
#   'store,': 1,
#   'friends': 1,
#   'gasbags': 1,
#   'lady': 2,
#   'guy': 1,
#   'white': 1,
#   'ladies': 1,
#   'building.': 1,
#   'building': 1,
#   'to': 1,
#   'friend?': 1,
#   'comb?': 1,
#   'woman,': 1,
#   'king': 1,
#   'plan!': 1,
#   'Sun': 1,
#   'times': 1,
#   'days.': 1,
#   'master,': 1},
#  'days:': {'a': 1},
#  'a': {'time': 3,
#   'shot': 430,
#   'large': 136,
#   'small': 96,
#   'side': 21,
# ...
#  'same.': {'Reaching': 1,
#   '\nGAN_JIN_LEADER:': 1,
#   '\nIROH:': 2,
#   '\nSCENE_DESCRIPTION:': 1,
#   '\nMECHANIST:': 1,
#   '\nTEO:': 1,
#   'Aang': 1,
#   '\nAANG:': 1,
#   'Cut': 2},
#  'Reaching': {'the': 2},
#  'first,': {'Katara': 1,
#   'and': 1,
#   'I': 2,
#   '[Shot': 1,
#   'Katara,': 1,
#   'my': 1,
#   'destroying': 1,
#   'passing': 1,
#   'but': 1,
#   "'cause": 1},
#  'repeatedly': {'strikes': 1,
#   'in': 3,
#   'sends': 1,
#   'at': 1,
#   'bangs': 1,
#   'to': 1},
#  'strikes': {'the': 9,
#   'Zuko': 1,
#   "Aang's": 1,
#   'a': 2,
#   'dead': 1,
#   'her': 1,
#   'his': 2,
#   'again,': 2,
#   'deterred': 1,
#   'at': 2,
#   'Jet': 1,
#   'down': 1,
#   'him': 1,
#   'out': 1,
#   'four': 1,
#   'above': 1,
#   'Sokka.': 1,
#   'in': 1},
#  'club.': {'On': 1, 'He': 2, '\nSOKKA:': 2, 'Flashback': 1},
#  'On': {'her': 1,
#   'a': 2,
#   'my': 2,
#   'the': 13,
#   'second': 2,
#   'board,': 1,
#   'that': 1,
#   'your': 1,
#   'one': 3,
#   'top': 1,
#   'Ji.': 2,
#   "Ji's": 1,
#   'Ji,': 2,
#   'Ji': 4,
#   'Ji.]': 1,
#   'wedding': 1,
#   'another': 1,
#   'Appa?': 1,
#   'patrol': 1,
#   'stage,': 1},
#  'fifth': {'strike,': 1, 'in': 1},
#  'strike,': {'the': 1, 'melting': 1, 'but': 2},
#  'great': {'gust': 1,
#   'Commander': 1,
#   'leader.': 3,
#   'job': 1,
#   'here.': 1,
#   'man.': 1,
#   'bridge': 3,
#   'city': 2,
#   'danger': 1,
#   'teacher.': 2,
#   'bargain!': 1,
#   'idea.': 2,
#   'score.': 1,
#   'bending': 1,
#   'victory': 1,
#   'eastern': 1,
#   'western': 1,
#   'Avatar.': 1,
#   'romance': 1,
#   'battle,': 1,
#   'year': 1,
#   'plumes.': 1,
#   'guy': 1,
#   'joy': 1,
#   'to': 4,
#   'place': 2,
#   'man,': 1,
#   'man!': 1,
#   'benders': 1,
#   'master.': 1,
#   'grandpa': 1,
#   'nation.': 1,
#   'Ocean': 1,
#   'job.': 1,
#   'Admiral': 1,
#   'sadness': 1,
#   'spirits.': 1,
#   'and': 4,
#   'Zhao,': 1,
#   'heroes!': 1,
#   'news.': 1,
#   'kindness.': 1,
#   'Earth': 1,
#   'speed.': 2,
#   'interest.': 1,
#   'society': 1,
#   'Appa': 1,
#   'them.': 1,
#   'earthbender!': 1,
#   'teacher,': 1,
#   'campsite.': 1,
#   'wig!': 1,
#   'beard!': 1,
#   'for': 1,
#   'new': 1,
#   'Knowledge': 1,
#   'spirit,': 1,
#   'team': 1,
#   'honor': 2,
#   'make-up.': 1,
#   'blessing.': 1,
#   'with': 2,
#   'amount': 1,
#   'beast.': 1,
#   'metropolis': 1,
#   'fear,': 1,
#   'loss.': 1,
#   'warrior': 1,
#   'warrior.': 1,
#   'tea!': 1,
#   'power,': 1,
#   'walls': 1,
#   'March': 1,
#   'swordsman.': 1,
#   'place,': 1,
#   'all': 1,
#   'comet': 1,
#   'good': 1,
#   'evil.': 1,
#   'force.': 1,
#   'we': 1,
#   'climber!': 1,
#   'dragon': 1,
#   'about': 1,
#   'dance': 1,
#   'masters': 1,
#   'era': 1,
#   'idea!': 1},
#  'gust': {'of': 17, 'from': 1, 'at': 2, 'forces': 1},
#  'wind,': {'which': 1,
#   'along': 1,
#   'a': 1,
#   'he': 1,
#   'revealing': 1,
#   'sending': 1},
#  'escapes': {'from': 1,
#   'by': 1,
#   'the': 1,
#   'into': 1,
#   'a': 1,
#   'through': 3,
#   'as': 1,
#   'and': 1},
#  'throws': {'her': 7,
#   'his': 18,
#   'it': 19,
#   'the': 22,
#   'up': 2,
#   'Sokka': 1,
#   'a': 14,
#   'aside': 1,
#   'himself': 2,
#   'money': 1,
#   'another': 2,
#   'them': 6,
#   'him': 7,
#   'more': 1,
#   'four': 1,
#   'objects': 1,
#   'an': 2,
#   'three': 2,
#   'down': 2,
#   'out': 1,
#   'glue': 1,
#   'Zuko': 2,
#   'multiple': 1,
#   'Toph': 1,
#   'two': 2,
#   'at': 1},
#  'dome.': {'Fissures': 1, '\nZEI:': 1, 'Cut': 1},
#  'Fissures': {'quickly': 1},
#  'whole': {'iceberg': 1,
#   'South': 2,
#   'time!': 2,
#   'front': 1,
#   'scene': 1,
#   'body.]': 1,
#   'temple': 1,
#   'Avatar': 1,
#   'face.]': 1,
#   'village?': 1,
#   'the': 1,
#   'place': 4,
#   'system': 1,
#   'army': 1,
#   'valley.': 1,
#   'town?': 1,
#   'tribe': 1,
#   'canyon': 1,
#   'point': 2,
#   'thing': 2,
#   'world!': 1,
#   'life.': 2,
#   'village.': 1,
#   'time.]': 1,
#   'barrel': 1,
#   'time?': 2,
#   'different': 1,
#   'life': 2,
#   'place.': 1,
#   'mess': 1,
#   'oasis': 1,
#   'ordeal,': 1,
#   'labyrinth!': 1,
#   'body.\nThe': 1,
#   'top': 1,
#   'swamp': 1,
#   'world?': 1,
#   'effigy.': 1,
#   'nation': 1,
#   'peninsula': 1,
#   'amphitheater': 1,
#   'alley,': 1,
#   'year': 1,
#   'world.': 2,
#   'time.': 1,
#   'identity.': 1,
#   'earthbending': 1,
#   'time,': 1,
#   'world': 5,
#   'thing.': 2,
#   'room,': 1,
#   'city': 2,
#   'reason': 1,
#   'Earth': 1,
#   'palace': 1,
#   'history': 1,
#   'outfit.]': 1,
#   'day.': 1,
#   'mission': 1,
#   'life,': 2,
#   'village': 1,
#   'day': 1,
#   'tray': 1,
#   'invasion.': 1,
#   'head!': 1,
#   'team,': 1,
#   'stage.]': 1,
#   'island': 1},
#  'and,': {'in': 3,
#   'well': 1,
#   'without': 1,
#   'obeying': 1,
#   '[Picks': 1,
#   'I': 1,
#   'turning': 1,
#   'using': 1,
#   'by': 1,
#   'dangling': 1,
#   'once': 1,
#   'seeing': 1,
#   'as': 1,
#   'we': 1},
#  'explosion,': {'the': 1,
#   'so': 1,
#   'producing': 1,
#   'sending': 1,
#   'followed': 1},
#  'entire': {'orb': 1,
#   'village.': 1,
#   'Southern': 1,
#   'village.\nCut': 1,
#   'room,': 2,
#   'team': 3,
#   'group': 7,
#   'dorsal': 1,
#   'lake': 2,
#   'uniform': 1,
#   'pyramid': 1,
#   'table.': 1,
#   'city': 3,
#   'body,': 1,
#   'city.': 2,
#   'earth': 1,
#   'rig!': 1,
#   'place': 1,
#   'marketplace.': 1,
#   'world.': 3,
#   'division': 1,
#   'conversation.': 1,
#   'group,': 3,
#   'courtyard,': 1,
#   'ship': 2,
#   'room': 3,
#   'room.': 1,
#   'hut': 1,
#   'world': 1,
#   'culture.': 1,
#   'fleet': 1,
#   'North': 1,
#   'globule': 1,
#   'culture': 1,
#   'Water': 1,
#   'gang': 1,
#   'room.]': 1,
#   'Fire': 1,
#   'desk': 1,
#   'arena,': 1,
#   'field': 2,
#   'campsite,': 1,
#   'inside': 1,
#   'ecosystem': 1,
#   'thing': 1,
#   'the': 1,
#   'class': 1,
#   'village': 1,
#   'group.]': 2,
#   'party': 1,
#   'world!': 1,
#   'hot': 1,
#   'campsite': 1,
#   'village,': 1,
#   'throne': 1,
#   'bag': 1,
#   'prison': 1,
#   'culture,': 1,
#   'crowd': 1,
#   'palace': 2,
#   'sun.': 1,
#   'palace,': 1,
#   'battlefield,': 1,
#   'courtyard': 1,
#   'hallway,': 1,
#   'cell,': 2,
#   'scenario.': 1,
#   'campsite.': 1,
#   'cliff': 1,
#   'trio.]': 1,
#   'clearing': 1,
#   'buildings': 1,
#   'life.': 1,
#   'island': 1,
#   'eel': 1,
#   'group.': 1,
#   'creature': 1},
#  'orb': {'of': 1, 'from': 4, 'with': 1, 'was': 2, 'into': 1},
#  'destroys': {'itself.': 1,
#   'the': 15,
#   'them': 1,
#   'everything': 1,
#   'a': 2,
#   'it': 2,
#   'several': 1,
#   "Aang's": 1,
#   'it.': 1},
#  'itself.': {'A': 1, 'When': 1, 'But': 1, '[Begins': 1, '[Normal': 1},
#  'beam': {'of': 9,
#   'to': 2,
#   'only': 1,
#   'thus': 1,
#   'down': 1,
#   'from': 1,
#   'and': 2,
#   'together,': 1,
#   'disappears': 1},
#  'core': {'of': 1},
#  'rockets': {'into': 1,
#   'upward': 1,
#   'at': 1,
#   'forward.': 1,
#   'from': 1,
#   'up': 1},
#  'sky.': {'The': 11,
#   "You'll": 1,
#   '\nVILLAGE_GIRL:': 1,
#   'Curious,': 1,
#   '\nAANG:': 1,
#   'Sokka': 2,
#   'They': 1,
#   'Close-up': 1,
#   '\nKATARA:': 3,
#   'Cut': 6,
#   '\nIROH:': 1,
#   '\nSOKKA:': 2,
#   'Aang': 1,
#   'Aang,': 1,
#   "That's": 1,
#   'Now!': 1,
#   '\nYUE:': 1,
#   '\nLO:': 1,
#   '\nAZULA:': 1,
#   '\nKING_BUMI:': 1,
#   'Cuts': 2,
#   'She': 1,
#   'Katara': 2,
#   'He': 1,
#   'Toph': 1,
#   'As': 1,
#   'Suddenly,': 1,
#   'A': 1,
#   '\nYOUNG_KATARA:': 1,
#   '\nLION_TURTLE:': 1},
#  'shallow': {'sea': 1, 'old': 1, 'and': 1},
#  'bottom': {'as': 1,
#   'of': 19,
#   'and': 2,
#   'sides': 1,
#   'to': 1,
#   'eyelids': 1,
#   'opens.': 1},
#  'emits': {'ripples': 1, 'an': 1, 'from': 1, 'another': 1},
#  'ripples': {'of': 1, 'betray': 1},
#  'light.': {'The': 3,
#   'His': 1,
#   '\nAANG:': 1,
#   'They': 1,
#   'Cut': 5,
#   'Sokka': 1,
#   '\nIROH:': 1,
#   'Inside,': 1,
#   'Avatar': 1,
#   'It': 1,
#   'Both': 1,
#   '[Cuts': 1,
#   '\nZUKO:': 1,
#   'Now': 1,
#   '\nSCENE_DESCRIPTION:': 1},
#  'switches': {'to': 97,
#   'for': 1,
#   'over': 4,
#   'back': 7,
#   'again': 1,
#   'from': 2,
#   'position': 2,
#   'between': 1,
#   'to\xa0Katara': 1,
#   'into': 1,
#   'with': 1,
#   'view': 1,
#   'hats': 1},
#  'group': {'of': 34,
#   'begins': 2,
#   'has': 2,
#   'mounted': 1,
#   'and': 6,
#   'earlier.': 1,
#   'before': 3,
#   'flying': 1,
#   'to': 3,
#   'taking': 1,
#   'leaps': 1,
#   'tip-toes': 1,
#   'enters': 1,
#   'through': 1,
#   'up': 1,
#   'runs': 2,
#   'trudges': 1,
#   'sits': 1,
#   'eats,': 1,
#   'standing': 6,
#   'now': 3,
#   'coursing': 1,
#   'in': 3,
#   'walking': 4,
#   'on': 4,
#   'approaching.': 2,
#   'smiles': 1,
#   'comes': 1,
#   'lands': 1,
#   'is': 6,
#   'into': 1,
#   'rises;': 1,
#   'a': 1,
#   'leaves': 1,
#   'witnesses': 1,
#   'are': 2,
#   'as': 12,
#   'proceeds': 1,
#   'follows': 1,
#   'surrounding': 1,
#   'from': 4,
#   'shot,': 1,
#   'who': 1,
#   'starts': 2,
#   'sighs': 1,
#   'gazes': 1,
#   'arrives': 1,
#   'name.': 1,
#   'races': 1,
#   'looks': 2,
#   'down': 1,
#   'arrives,': 1,
#   'hug.': 4,
#   'gets': 1,
#   'lowers': 1,
#   'get': 1,
#   'looking': 1,
#   "who's": 1,
#   'leaving': 1,
#   'eating': 1,
#   'sitting': 5,
#   'hugs.]': 1,
#   'continues': 1,
#   'should': 1,
#   'were': 1,
#   'rises': 1,
#   'laughs,': 1,
#   'also': 1,
#   'hugs.': 1,
#   'over.': 1,
#   'stops': 1,
#   'turn': 1,
#   'that': 1},
#  'tiger': {'seals,': 1, 'hook': 1},
#  'seals,': {'who': 2},
#  'erect': {'themselves': 1, 'flying': 1},
#  'growl': {'at': 2, 'distracts': 1, 'can': 1, 'of': 1},
#  'distant': {'beam': 1,
#   'mine': 1,
#   'ocean.': 1,
#   'side-view': 1,
#   'can': 1,
#   'boar-q-pine': 1},
#  'light.\nCut': {'to': 1},
#  'ship,': {'where': 8,
#   'staring': 1,
#   'elevated': 1,
#   'Aang': 2,
#   'now': 1,
#   'Sokka.': 1,
#   'the': 3,
#   'but': 2,
#   'while': 1,
#   'and': 1,
#   'with': 1,
#   'half': 1,
#   'several': 1,
#   'a': 1,
#   'having': 1,
#   'which': 1,
#   'along': 1,
#   'bringing': 1,
#   'sailing': 1,
#   'Zhao': 1,
#   'however,': 1,
#   'hear': 1,
#   'Zuko': 1,
#   'allowing': 1,
#   'Katara': 1,
#   'peering': 1,
#   'he': 1,
#   'washing': 1,
#   'attacks': 1,
#   "Katara's": 1,
#   'garbed': 1,
#   'take': 1,
#   'striking': 1,
#   'planting': 1},
#  'military': {'uniform': 1,
#   'consultant,': 1,
#   'uniform.': 1,
#   'disgrace': 1,
#   'activities.': 1,
#   'are': 1},
#  'uniform': {'stands': 1, 'close': 1, 'that': 1, 'again?': 1},
#  'deck,': {'gazing': 1,
#   'Aang': 1,
#   'as': 1,
#   'encasing': 1,
#   'having': 1,
#   'untouched.': 1,
#   'Zuko': 1,
#   'where': 2,
#   'with': 1,
#   'inadvertently': 1,
#   'a': 1,
#   'paralyzed,': 1,
#   'triumphant.\nHe': 1,
#   'leaving': 1,
#   'the': 1,
#   'coughing.': 1},
#  'gazing': {'at': 2, 'villagers.': 1, 'out': 1, 'toward': 1, 'back': 1},
#  'ponytail': {'flutters': 1,
#   'back,': 1,
#   'in': 1,
#   'guy.': 1,
#   "who's": 1,
#   'Zuko': 1},
#  'flutters': {'in': 1, 'off.': 1, 'around': 1},
#  'wind.': {'\nZUKO:': 1,
#   '\nAANG:': 1,
#   'The': 1,
#   'With': 1,
#   '\nSOKKA:': 1,
#   'Camera': 1,
#   'Pretty': 1,
#   '\nROKU:': 1,
#   'Cuts': 2,
#   '\nKATARA:': 1,
#   'She': 1,
#   '\nTOPH:': 1},
#  '\nZUKO:': {'Finally!': 2,
#   '[Turning': 7,
#   '[Gestures': 2,
#   '[Furiously,': 1,
#   'Because': 4,
#   '[With': 3,
#   '[The': 3,
#   'The': 11,
#   '[Angrily.]': 15,
#   '[Shaking': 2,
#   '[Shocked.]': 10,
#   "I've": 5,
#   '[Boarding': 1,
#   'This': 4,
#   'Looks': 1,
#   '[Holding': 1,
#   '[Slightly': 2,
#   'Uncle,': 7,
#   '[Turns': 10,
#   'Yes.': 2,
#   '[Looks': 3,
#   '[He': 12,
#   '[Close-up.': 4,
#   '[Aggressively.]': 1,
#   '[Faces': 2,
#   'I': 48,
#   '[Alarmed.]': 1,
#   '[Angrily': 2,
#   '[Cut': 25,
#   '[Furiously.]': 1,
#   'An': 1,
#   '[Darkly.]': 1,
#   '[Close-up': 5,
#   '[Anger': 1,
#   '[Softly.]': 1,
#   '[Calmly.]': 2,
#   '[Enraged.]': 1,
#   '[Desperately.]': 1,
#   '[Yells': 1,
#   '[Frog': 1,
#   'Nice': 2,
#   'Back': 2,
#   'Uncle!': 4,
#   'Uncle?': 4,
#   'My': 6,
#   'Enough!': 1,
#   '[Shielding': 1,
#   "Something's": 2,
#   'Land': 1,
#   '[Sniffs': 1,
#   'You': 24,
#   'Now': 4,
#   '[Breaks': 1,
#   '[Lights': 1,
#   "He's": 1,
#   '[Lowers': 2,
#   '[Spins': 1,
#   '[Confidently.]': 1,
#   '[Close-up.]': 7,
#   '[Steps': 1,
#   '[Firmly': 1,
#   '[Strains': 1,
#   '[Storming': 1,
#   '[Hopefully.]': 1,
#   '[Confused.]': 2,
#   '[In': 4,
#   "It's": 12,
#   '[Turning.]': 1,
#   'We': 10,
#   'Then': 2,
#   'Tell': 2,
#   'Try': 1,
#   '[To': 8,
#   "Don't": 1,
#   'Shut': 1,
#   "You'll": 2,
#   '[Off': 1,
#   "You're": 8,
#   '[Taking': 1,
#   'Finding': 1,
#   '[Whirling': 1,
#   'Where': 1,
#   'Let': 3,
#   'What': 13,
#   '[Looking': 3,
#   'Off': 1,
#   "I'm": 16,
#   '[Arrives': 1,
#   'But': 10,
#   '[Annoyed.]': 5,
#   'Your': 4,
#   'Money': 1,
#   'If': 8,
#   "We're": 3,
#   'Hey!': 2,
#   'How': 4,
#   "What's": 8,
#   'For': 2,
#   '[Bitterly.]': 2,
#   '[Hearing': 1,
#   'Thank': 2,
#   '[Removes': 1,
#   "I'll": 2,
#   '[Peering': 1,
#   '[Sarcastically.]': 5,
#   '[Determined.]': 3,
#   '[Rising.]': 1,
#   'Shelter.': 1,
#   'Guess': 1,
#   'Welcome': 1,
#   '[Zuko': 5,
#   '[Throwing': 1,
#   'Take': 1,
#   '[Surprised.]': 3,
#   '[Packing': 1,
#   'Did': 2,
#   '[Wistfully.]': 1,
#   '[Emerging': 1,
#   '[Grabbing': 1,
#   '[Nodding': 1,
#   '[Nervously;': 1,
#   'Names?': 1,
#   '[Sets': 1,
#   "They're": 2,
#   '[Angrily,': 2,
#   '[Lazily': 1,
#   "There's": 4,
#   'Uncle': 3,
#   'Could': 1,
#   'No.': 4,
#   'No': 3,
#   '[Nervously.]': 1,
#   'Keep': 1,
#   'Trouble.': 1,
#   'Here.': 1,
#   'Azula': 1,
#   '[Stands': 4,
#   'It': 9,
#   'Yes,': 1,
#   '[Horrified.]': 1,
#   '[Blasts': 1,
#   '[Hands': 1,
#   'So': 6,
#   'Why': 6,
#   'Well,': 10,
#   'All': 1,
#   'Great,': 1,
#   "You've": 1,
#   'Maybe': 2,
#   'Too': 1,
#   'Ba': 1,
#   'Look': 1,
#   'Hello.': 1,
#   '[Tosses': 1,
#   '[Disgusted.]': 1,
#   'Thanks,': 1,
#   '[Walking': 1,
#   '[Gritting': 1,
#   '[Bleakly.]': 1,
#   '[Iroh': 1,
#   '[Bewildered.]': 1,
#   'Nothing.': 1,
#   'Umm': 1,
#   'Close': 1,
#   'Okay,': 3,
#   '[Stops': 3,
#   '[Sitting': 2,
#   '[Shows': 1,
#   'Out': 1,
#   'Expecting': 1,
#   '[Sighs': 2,
#   'First': 2,
#   'Stop': 1,
#   '[Sniffs.]': 1,
#   '[Optimistically.]': 1,
#   'Congratulations,': 1,
#   'No!': 1,
#   'Yes!': 1,
#   'What?': 3,
#   'Why,': 1,
#   'Release': 1,
#   'So,': 4,
#   "Why'd": 1,
#   'It.': 1,
#   '[Snickers.]': 1,
#   "Can't": 1,
#   '[Standing': 2,
#   '[Sits': 1,
#   '[Sliding': 1,
#   '[Frontal': 10,
#   '[Whispering.]': 4,
#   '[Picks': 1,
#   '[Closer': 1,
#   '[Side-view': 5,
#   'Sure.': 1,
#   '[Angered.]': 1,
#   '[Snapping': 1,
#   '[Side-view.]': 1,
#   '[View': 1,
#   '[Side-view;': 1,
#   '[Walks': 3,
#   '[Camera': 3,
#   '[Aerial': 2,
#   'Bad': 1,
#   '[Reading': 2,
#   'Wait,': 1,
#   '[Reading.]': 1,
#   'That': 2,
#   'Oh,': 2,
#   'And': 2,
#   'Forget': 1,
#   '[Sighs.]': 1,
#   'When': 1,
#   'During': 1,
#   'In': 1,
#   "That's": 8,
#   '[Pulls': 1,
#   'No,': 4,
#   'After': 1,
#   '[Grows': 1,
#   'Hello': 1,
#   'Hey,': 2,
#   'Right.': 1,
#   'Look,': 1,
#   'Uggh!': 1,
#   "Who's": 1,
#   'Stop!': 2,
#   'Listen,': 1,
#   '[Bows.]': 1,
#   '[Excitedly': 1,
#   '[Takes': 1,
#   '[Frustrated.]': 2,
#   'Just': 2,
#   '[Very': 1,
#   '[Raises': 2,
#   'Listen': 1,
#   "We've": 1,
#   'Even': 1,
#   '[Kneeling': 1,
#   '[Dusting': 1,
#   'He': 2,
#   'Wait.': 2,
#   'Relax.': 1,
#   'Ugh,': 1,
#   'Me?': 1,
#   'At': 2,
#   'Who': 1,
#   'Think': 2,
#   'Hurry': 1,
#   'Bring': 1,
#   'Sshh.': 1,
#   '[Unwillingly.]': 1,
#   '[Surprised.': 1,
#   'Yeah.': 1,
#   '[Embarrassed.]': 1,
#   'Okay.': 1,
#   'Trust': 1,
#   'Not': 1,
#   'Yeah': 2,
#   '[Downcast.]': 1,
#   '[Smiles.]': 1,
#   '[Shocked': 1,
#   'There': 1,
#   '[Frantically': 1,
#   '[Falls': 1,
#   'Uh,': 1,
#   'Can': 1,
#   'Hey': 1,
#   'Shhh!': 1,
#   'Yeah,': 3,
#   'Ah,': 1,
#   '[Shot': 1,
#   '[Even': 1,
#   '[Folds': 1,
#   '[Exchanges': 1,
#   "Someone's": 1,
#   'War': 1,
#   'Are': 1,
#   '[Sokka': 1,
#   '[Grabs': 1,
#   'Is': 1,
#   '[A': 1,
#   '[Voice-over.]': 4,
#   'But,': 1,
#   '[Gives': 1,
#   '[Groans.]': 1,
#   'Me': 1,
#   '[As': 1,
#   'Go': 2,
#   "She's": 1,
#   '[Jokingly.]': 1,
#   '[Smiling.]': 1,
#   '[Closes': 1,
#   'Sorry,': 2,
#   '[Interrupting': 1,
#   'Katara': 1,
#   'Sokka': 1,
#   'She': 1,
#   'There!': 1,
#   '[Bending': 1,
#   '[Recalling': 1,
#   '[Removing': 1,
#   'Really?': 1,
#   'Ow!': 1,
#   'More': 2,
#   "[Zuko's": 1,
#   '[Lets': 1,
#   'Teaching': 1,
#   'Exactly.': 1,
#   'Once,': 1,
#   'Like': 1,
#   '[Bluntly.]': 1,
#   '[Puts': 2,
#   'Aang?': 1,
#   'Uh-huh.': 1,
#   'Get': 1,
#   '[Pointing.]': 1,
#   'Yup.': 1,
#   '[Speaking': 1,
#   '[Angrily;': 1,
#   '[Nonchalantly.]': 1,
#   '[Extreme': 1,
#   '[Seriously.]': 1,
#   '[Getting': 1,
#   'Mai!': 1,
#   'Please.': 1,
#   'Banishing': 1},
#  'Finally!': {'[He': 1,
#   '\nSCENE_DESCRIPTION:': 1,
#   '[Close-up': 1,
#   '[To': 1,
#   "Let's": 1,
#   'Solid': 1},
#  'person': {'in': 4,
#   'I': 2,
#   'is': 4,
#   'coughs.]': 1,
#   '...': 2,
#   'ever': 1,
#   'to': 4,
#   'now.': 1,
#   'with': 1,
#   'places': 1,
#   'that': 1,
#   'or': 1,
#   'talking': 1,
#   'than': 1,
#   'you': 1,
#   'and': 1,
#   'who': 1,
#   'missing.': 1,
#   'anymore!': 1,
#   'being': 1,
#   'involved': 1,
#   'could': 1,
#   'other': 1},
#  'uniform,': {'who': 1, 'you': 1},
#  'sits': {'at': 4,
#   'down': 20,
#   'on': 18,
#   'atop': 1,
#   'down.]': 5,
#   'up,': 3,
#   'down.': 4,
#   'back': 3,
#   'in': 9,
#   'up': 11,
#   'beside': 2,
#   'there': 2,
#   'next': 7,
#   'him': 1,
#   'down,': 4,
#   'across': 1,
#   'and': 4,
#   'cross-legged': 1,
#   'cross-legged,': 1,
#   'up.': 4,
#   'behind': 1,
#   'smiling,': 1,
#   'empty': 1,
#   'with': 2,
#   'lays': 1,
#   'casually,': 1,
#   'near': 1,
#   'before': 1,
#   'nearby': 1,
#   'to': 1},
#  ...}

# %%
import numpy as np
from scipy import stats

# %%
current_word = "\nKatara:".upper()
print(current_word, end=' ')
for i in range(100):
    probability_of_next_word = np.array(list(next_word[current_word].values()))/word_used[current_word]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word = np.array(list(next_word[current_word].keys()))[1==randomly_chosen_next_word][0]
    print(current_word, end=' ')
# Out:
# KATARA: [Walking back in your name, Flopsie turns and pushes Zuko delivers the final touches every direction. Sokka watching the woods.
# SCENE_DESCRIPTION: Sokka stroll through a large drill from both stand and they go to Aang continues to a side-view of the prison riot.
# SUKI: It doesn't have taken a sweating Sokka.] They're giving each other; the Southern shores of light finally found Monk Tashi airbends to be together.
# OZAI: Prince Zuko?
# SOKKA: Then, Katara at each member punches Katara's on it, you get higher. Uhhh!
# SCENE_DESCRIPTION: Group of it. [Tosses the bridge guy, could get moving. A back to fight

# %%
import re
avatar.full_text = avatar.full_text.apply(lambda string: re.sub(r'\[.*?\]', lambda match: match.group(0).replace(' ', '_ '), string))
avatar.loc[avatar.character=='Scene Description','full_text'] = avatar.full_text[avatar.character=='Scene Description'].str.replace(' ', '- ')
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# %%
avatar[:10]
# Out:
#    id   book  book_num                 chapter  chapter_num  \
# 0   1  Water         1  The Boy in the Iceberg            1
# 1   2  Water         1  The Boy in the Iceberg            1
# 2   3  Water         1  The Boy in the Iceberg            1
# 3   4  Water         1  The Boy in the Iceberg            1
# 4   5  Water         1  The Boy in the Iceberg            1
# 5   6  Water         1  The Boy in the Iceberg            1
# 6   7  Water         1  The Boy in the Iceberg            1
# 7   8  Water         1  The Boy in the Iceberg            1
# 8   9  Water         1  The Boy in the Iceberg            1
# 9  10  Water         1  The Boy in the Iceberg            1
#
#            character                                          full_text  \
# 0             Katara  Water. Earth. Fire. Air. My grandmother used t...
# 1  Scene Description  As- the- title- card- fades,- the- scene- open...
# 2              Sokka  It's not getting away from me this time. [Clos...
# 3  Scene Description  The- shot- pans- quickly- from- the- boy- to- ...
# 4             Katara                 [Happily_ surprised.] Sokka, look!
# 5              Sokka  [Close-up_ of_ Sokka;_ whispering.] Sshh! Kata...
# 6  Scene Description  Behind- Sokka,- Katara- is- still- making- cir...
# 7             Katara  [Struggling_ with_ the_ water_ that_ passes_ r...
# 8  Scene Description  The- bubble- containing- her- fish- slowly- dr...
# 9             Katara                      [Exclaims_ indignantly.] Hey!
#
#                                      character_words  \
# 0  Water. Earth. Fire. Air. My grandmother used t...
# 1                                                NaN
# 2  It's not getting away from me this time.  Watc...
# 3                                                NaN
# 4                                       Sokka, look!
# 5  Sshh! Katara, you're going to scare it away.  ...
# 6                                                NaN
# 7                          But, Sokka! I caught one!
# 8                                                NaN
# 9                                               Hey!
#
#                                               writer     director  imdb_rating
# 0  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 1  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 2  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 3  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 4  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 5  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 6  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 7  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 8  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1
# 9  ‎Michael Dante DiMartino, Bryan Konietzko, Aar...  Dave Filoni          8.1

# %%
word_used2 = defaultdict(int)
next_word2 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-2]):
    word_used2[word+' '+words[i+1]] += 1
    next_word2[word+' '+words[i+1]][words[i+2]] += 1

# %%
next_word2
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'\nKATARA: Water.': defaultdict(int, {'Earth.': 2}),
#              'Water. Earth.': defaultdict(int, {'Fire.': 2}),
#              'Earth. Fire.': defaultdict(int, {'Air.': 2}),
#              'Fire. Air.': defaultdict(int, {'My': 1, 'Long': 1}),
#              'Air. My': defaultdict(int, {'grandmother': 1}),
#              'My grandmother': defaultdict(int, {'used': 1, 'gave': 1}),
#              'grandmother used': defaultdict(int, {'to': 1}),
#              'used to': defaultdict(int,
#                          {'tell': 2,
#                           'be': 7,
#                           'always': 2,
#                           'kind': 1,
#                           'hang': 1,
#                           'have': 1,
#                           'come': 4,
#                           'calling': 1,
#                           'show': 1,
#                           'be.': 2,
#                           'each': 1,
#                           'say': 2,
#                           'it.': 1,
#                           'think': 1,
#                           'be,': 1,
#                           'visit': 1,
#                           'people': 1,
#                           'live': 1,
#                           'mention': 1,
#                           'escape.': 1,
#                           'take': 1}),
#              'to tell': defaultdict(int,
#                          {'me': 8,
#                           'ya': 1,
#                           'you,': 3,
#                           'you': 9,
#                           'your': 1,
#                           'you.': 1,
#                           'everything': 1,
#                           'you:': 1,
#                           "'em": 1,
#                           'her': 1,
#                           'you?': 1,
#                           'before': 1,
#                           'them': 1,
#                           'the': 2,
#                           'me.': 2,
#                           'us': 1,
#                           'if': 1}),
#              'tell me': defaultdict(int,
#                          {'stories': 1,
#                           'what': 4,
#                           'who': 1,
#                           'we': 3,
#                           'something': 1,
#                           'twice.': 1,
#                           'about': 3,
#                           'you': 3,
#                           'that': 2,
#                           'your': 1,
#                           'no!': 1,
#                           'if': 1,
#                           "you're": 2,
#                           '...': 2,
#                           'where': 1,
#                           'everything': 1,
#                           'anything?': 1,
#                           "what's": 1,
#                           'he': 1,
#                           'something.': 1}),
#              'me stories': defaultdict(int, {'about': 1}),
#              'stories about': defaultdict(int, {'the': 2, 'you!': 1}),
#              'about the': defaultdict(int,
#                          {'old': 1,
#                           'North': 1,
#                           'airbenders.': 1,
#                           'Avatar.': 1,
#                           'challenges.': 1,
#                           'Spirit': 1,
#                           'people': 1,
#                           'forest': 1,
#                           'wait,': 1,
#                           'storm': 1,
#                           'volcano.': 1,
#                           'air.': 1,
#                           'great': 1,
#                           'tides.': 1,
#                           'tides': 1,
#                           'visions?': 1,
#                           'swamp.': 1,
#                           'wrong': 1,
#                           'tank': 1,
#                           'Misty': 1,
#                           'solar': 2,
#                           'Dragon': 1,
#                           'Fire': 4,
#                           'War,': 1,
#                           'war': 2,
#                           'war?': 1,
#                           'rules': 1,
#                           'Jasmine': 1,
#                           'invasion?': 1,
#                           'secret': 1,
#                           'state': 1,
#                           'spirit': 1,
#                           'lilies,': 1,
#                           'math': 1,
#                           'invasion': 1,
#                           'original': 1,
#                           'prison?': 1,
#                           'soldiers': 1,
#                           'sandbenders': 1,
#                           'Avatar': 1,
#                           'world.': 1,
#                           'rest': 1}),
#              'the old': defaultdict(int,
#                          {'days:': 1,
#                           'man': 2,
#                           'general': 1,
#                           'war': 1,
#                           'guy': 1,
#                           'plan!': 1}),
#              'old days:': defaultdict(int, {'a': 1}),
#              'days: a': defaultdict(int, {'time': 1}),
#              'a time': defaultdict(int, {'of': 1, 'limit.': 1, 'when': 1}),
#              'time of': defaultdict(int, {'peace': 2}),
#              'of peace': defaultdict(int, {'when': 1, 'and': 3}),
#              'peace when': defaultdict(int, {'the': 1}),
#              'when the': defaultdict(int,
#                          {'Avatar': 1,
#                           'Fire': 4,
#                           'world': 2,
#                           'sneaky': 1,
#                           'Water': 1,
#                           'monks': 1,
#                           'time': 2,
#                           'tree': 1,
#                           'next': 2,
#                           'eclipse': 1,
#                           'Dai': 1,
#                           'raids': 1,
#                           'firebenders': 1,
#                           'new': 1}),
#              'the Avatar': defaultdict(int,
#                          {'kept': 1,
#                           'mastered': 1,
#                           'was': 4,
#                           'will': 5,
#                           'is': 12,
#                           'to': 7,
#                           'going?': 1,
#                           'in': 2,
#                           'for': 3,
#                           'Cycle.': 1,
#                           'dies,': 1,
#                           'before': 2,
#                           '...': 4,
#                           'alive.': 1,
#                           'would': 3,
#                           'has': 3,
#                           'himself?': 1,
#                           'speaking.': 1,
#                           'and': 7,
#                           'stands': 1,
#                           'returned': 1,
#                           'lately?': 1,
#                           'contacts': 1,
#                           "won't": 1,
#                           'can': 3,
#                           'gives': 1,
#                           'is-': 1,
#                           'must': 1,
#                           'held.': 1,
#                           '[He_': 1,
#                           'State,': 8,
#                           'State.': 9,
#                           'State': 10,
#                           'State!': 2,
#                           'himself!': 1,
#                           'showed': 1,
#                           'so': 1,
#                           'around': 1,
#                           'a': 1,
#                           '[Jumps_': 1,
#                           'keeps': 1,
#                           'at': 1,
#                           'journey.': 1,
#                           'State?': 1,
#                           'forever.': 1,
#                           'fell!': 1,
#                           "doesn't": 2,
#                           'we': 1,
#                           "hasn't": 1,
#                           'firebending.': 1,
#                           'anymore!': 1,
#                           'are': 1,
#                           'myself!': 1,
#                           'who': 1,
#                           'spared': 1}),
#              'Avatar kept': defaultdict(int, {'balance': 1}),
#              'kept balance': defaultdict(int, {'between': 1}),
#              'balance between': defaultdict(int, {'the': 1}),
#              'between the': defaultdict(int,
#                          {'Water': 1,
#                           'worlds,': 1,
#                           'forces': 1,
#                           'two': 2,
#                           'pools': 1,
#                           'toes.': 1}),
#              'the Water': defaultdict(int,
#                          {'Tribes,': 1,
#                           'Tribe,': 1,
#                           'Tribe!': 3,
#                           'Tribe.': 8,
#                           'Tribe': 6,
#                           "Tribe's": 1,
#                           'Tribe\u200c?': 1}),
#              'Water Tribes,': defaultdict(int, {'Earth': 1}),
#              'Tribes, Earth': defaultdict(int, {'Kingdom,': 1}),
#              'Earth Kingdom,': defaultdict(int,
#                          {'Fire': 1, 'and': 1, 'attack!': 1, '[Raises_': 1}),
#              'Kingdom, Fire': defaultdict(int, {'Nation': 1}),
#              'Fire Nation': defaultdict(int,
#                          {'and': 3,
#                           'attacked.': 2,
#                           'is': 9,
#                           'could': 1,
#                           'killed': 3,
#                           'has': 6,
#                           'from': 2,
#                           'invaded': 1,
#                           'spies?': 1,
#                           'been': 1,
#                           'do': 1,
#                           'invaded,': 1,
#                           'raid.': 2,
#                           'troops.': 1,
#                           '-': 1,
#                           'will': 4,
#                           'soldier.': 1,
#                           'with': 1,
#                           'waters': 1,
#                           'ships': 2,
#                           'captures': 1,
#                           'must': 1,
#                           'traps,': 1,
#                           'keep': 1,
#                           "can't": 4,
#                           'want': 1,
#                           'out': 1,
#                           'swine.': 1,
#                           'thinks': 2,
#                           'let': 1,
#                           'have': 3,
#                           'about': 1,
#                           'troops': 1,
#                           'today.': 1,
#                           'did': 2,
#                           'soldiers': 3,
#                           'destroyed': 1,
#                           'than': 1,
#                           'attacked': 2,
#                           'for': 1,
#                           'would': 1,
#                           'breaks': 1,
#                           'cultural': 1,
#                           'town': 1,
#                           'Soldier!': 1,
#                           'general,': 1,
#                           'on': 3,
#                           'Navy.': 1,
#                           "doesn't": 1,
#                           'will,': 1,
#                           'needs': 1,
#                           'takes': 1,
#                           'before.': 1,
#                           'discovers': 1,
#                           'raided': 1,
#                           'baby!': 1,
#                           'army.': 1,
#                           'governor.': 1,
#                           'Man!': 1,
#                           'national': 1,
#                           'uniforms': 1,
#                           'history."': 1,
#                           'should': 1,
#                           'history.': 3,
#                           'when': 3,
#                           'wanted': 1,
#                           'controls': 1,
#                           'cannot': 1,
#                           'that': 1,
#                           'spoon.': 1,
#                           'army': 1,
#                           'left': 1,
#                           'defenseless.': 1,
#                           'to': 3,
#                           'insignia': 1,
#                           "won't": 2,
#                           'this': 1,
#                           'ships!': 1,
#                           'as': 2,
#                           'heads?': 1,
#                           'princess': 1,
#                           'clutches!': 1,
#                           'took': 2,
#                           'princess!': 1,
#                           'history,': 1,
#                           'ship?': 1,
#                           'surged': 1,
#                           'ships.': 1,
#                           'ships,': 1,
#                           'vulnerable.': 1,
#                           'disguises,': 1,
#                           'colonies': 1,
#                           'school,': 1,
#                           'oath.': 1,
#                           'dances.': 1,
#                           'colonies,': 1,
#                           'colonials.': 1,
#                           'folks.': 1,
#                           'cover': 1,
#                           'are': 1,
#                           'battleship,': 1,
#                           'wiped': 1,
#                           'prison.': 2,
#                           'soldiers,': 1,
#                           'exploding': 1,
#                           'capital,': 2,
#                           'Royal': 1,
#                           'was': 1,
#                           'prisons.': 1,
#                           'or': 1,
#                           'assassin': 1,
#                           'palace.': 1,
#                           'people': 1}),
#              'Nation and': defaultdict(int, {'Air': 1, 'face': 1, 'I': 1}),
#              'and Air': defaultdict(int, {'Nomads.': 1}),
#              'Air Nomads.': defaultdict(int, {'But': 1, '[Cut_': 1}),
#              'Nomads. But': defaultdict(int, {'that': 1}),
#              'But that': defaultdict(int,
#                          {'all': 1, 'happened': 1, 'means': 1, 'was': 1}),
#              'that all': defaultdict(int,
#                          {'changed': 1,
#                           'about,': 1,
#                           'you': 1,
#                           'the': 1,
#                           'life': 1}),
#              'all changed': defaultdict(int, {'when': 1}),
#              'changed when': defaultdict(int, {'the': 2}),
#              'the Fire': defaultdict(int,
#                          {'Nation': 91,
#                           'Nation,': 18,
#                           'Navy!': 1,
#                           'Navy.': 1,
#                           "Nation's": 5,
#                           'Nation.': 46,
#                           'Navy': 2,
#                           'Lord.': 22,
#                           'Lord': 34,
#                           "Lord's": 11,
#                           'Temple': 1,
#                           'Sages.': 1,
#                           'Lord,': 6,
#                           'Lord?': 4,
#                           "Day's": 1,
#                           'Lord!': 3,
#                           'Nation!': 9,
#                           'Nation?!': 1,
#                           'Navy?': 1,
#                           'Nation?': 5,
#                           'Chakra,': 1,
#                           'Lord."': 1,
#                           'Sages': 2,
#                           'Temple!': 1,
#                           "Sages'": 1,
#                           'Prince': 1}),
#              'Nation attacked.': defaultdict(int, {'Only': 2}),
#              'attacked. Only': defaultdict(int, {'the': 2}),
#              'Only the': defaultdict(int,
#                          {'Avatar': 2, 'Avatar,': 1, 'king': 1, 'truly': 1}),
#              'Avatar mastered': defaultdict(int, {'all': 1}),
#              'mastered all': defaultdict(int, {'four': 2}),
#              'all four': defaultdict(int,
#                          {'elements;': 1,
#                           'elements,': 1,
#                           'elements': 2,
#                           'elements.': 1,
#                           'kinds': 1,
#                           'elements?': 1}),
#              'four elements;': defaultdict(int, {'only': 1}),
#              'elements; only': defaultdict(int, {'he': 1}),
#              'only he': defaultdict(int, {'could': 1}),
#              'he could': defaultdict(int,
#                          {'stop': 1,
#                           'figure': 1,
#                           'use': 1,
#                           'defeat': 1,
#                           'talk': 1,
#                           'have': 2,
#                           'master': 1,
#                           'go': 1,
#                           'capture': 1,
#                           'be': 1,
#                           'fool': 1}),
#              'could stop': defaultdict(int, {'the': 1, 'them,': 1}),
#              'stop the': defaultdict(int,
#                          {'ruthless': 1,
#                           'Fire': 3,
#                           'boat!': 1,
#                           'rock.': 1,
#                           'rock,': 1,
#                           'fire': 1,
#                           'airship': 1}),
#              'the ruthless': defaultdict(int, {'firebenders.': 1}),
#              'ruthless firebenders.': defaultdict(int, {'But': 1}),
#              'firebenders. But': defaultdict(int, {'when': 1}),
#              'But when': defaultdict(int,
#                          {'the': 1, 'have': 1, 'it': 1, 'you': 1}),
#              'the world': defaultdict(int,
#                          {'needed': 2,
#                           'will': 2,
#                           'safe.': 1,
#                           'by': 1,
#                           'is': 2,
#                           'until': 1,
#                           'to': 3,
#                           'from': 2,
#                           'in': 1,
#                           'alone,': 1,
#                           'needs': 1,
#                           'again,': 1,
#                           'of': 1,
#                           'so': 2,
#                           'lately.': 1,
#                           'once': 1,
#                           'are': 1,
#                           'that': 1,
#                           'awaits': 1,
#                           'would': 1,
#                           'sound': 1,
#                           'out': 1,
#                           'entered': 1,
#                           'scarred': 1}),
#              'world needed': defaultdict(int, {'him': 2, 'me': 1}),
#              'needed him': defaultdict(int, {'most,': 2}),
#              'him most,': defaultdict(int, {'he': 2}),
#              'most, he': defaultdict(int, {'vanished.': 2}),
#              'he vanished.': defaultdict(int, {'A': 2}),
#              'vanished. A': defaultdict(int, {'hundred': 2}),
#              'A hundred': defaultdict(int, {'years': 4, 'years!': 1}),
#              'hundred years': defaultdict(int,
#                          {'have': 1,
#                           'in': 2,
#                           'old': 1,
#                           'passed,': 1,
#                           'since': 1,
#                           'ago.': 9,
#                           'that': 1,
#                           'ago;': 1,
#                           'late!': 1,
#                           'ago,': 2,
#                           'ago': 3,
#                           'of': 3,
#                           'ago?': 1,
#                           'late.': 1,
#                           'can': 1}),
#              'years have': defaultdict(int, {'passed,': 1}),
#              'have passed,': defaultdict(int, {'and': 1}),
#              'passed, and': defaultdict(int, {'the': 1, 'my': 1}),
#              'and the': defaultdict(int,
#                          {'Fire': 7,
#                           'men': 1,
#                           'Avatar': 4,
#                           'other': 7,
#                           'courageous': 1,
#                           'Spirit': 3,
#                           'light': 1,
#                           'doors': 1,
#                           'little': 1,
#                           'only': 2,
#                           'time': 1,
#                           'whole': 1,
#                           'next,': 1,
#                           'Ocean': 1,
#                           'Moon': 2,
#                           'words': 1,
#                           'ocean.': 1,
#                           'Water': 1,
#                           'mountain': 1,
#                           "man's": 1,
#                           'tornado': 1,
#                           'accused.': 1,
#                           'superior': 1,
#                           'flying': 1,
#                           'energy': 1,
#                           'Rough': 1,
#                           'new': 1,
#                           'outer': 2,
#                           'ones': 1,
#                           'university.': 1,
#                           'Yum': 1,
#                           'day': 1,
#                           'young': 1,
#                           "Avatar's": 1,
#                           'War.': 1,
#                           'firebenders': 2,
#                           'military': 1,
#                           'foul': 1,
#                           'Council': 1,
#                           'angry': 1,
#                           'invasion': 2,
#                           'eclipse,': 1,
#                           'army': 1,
#                           'boat': 1,
#                           'rest': 2,
#                           'great': 1,
#                           'harbors': 1,
#                           'princess': 1,
#                           'nightmares.': 1,
#                           'swamp': 1,
#                           'eclipse': 1,
#                           'Avatar.': 1,
#                           'point': 1,
#                           'worst': 1,
#                           'world': 1,
#                           'comet': 1,
#                           'destiny': 1,
#                           'monks': 1}),
#              'Nation is': defaultdict(int,
#                          {'nearing': 1,
#                           'ruthless.': 1,
#                           'going': 1,
#                           'planning': 1,
#                           'gone': 1,
#                           'on': 1,
#                           'the': 1,
#                           'trying': 1,
#                           'falling': 1}),
#              'is nearing': defaultdict(int, {'victory': 1}),
#              'nearing victory': defaultdict(int, {'in': 1}),
#              'victory in': defaultdict(int, {'the': 2, 'this': 1}),
#              'in the': defaultdict(int,
#                          {'war.': 2,
#                           'water!': 3,
#                           'ice?': 1,
#                           'air!': 3,
#                           'village': 1,
#                           'body.': 1,
#                           'whole': 2,
#                           'meantime,': 1,
#                           'Fire': 16,
#                           'world!': 5,
#                           'way!': 1,
#                           'way': 3,
#                           'world.': 9,
#                           'gooey': 1,
#                           'iceberg': 2,
#                           'cycle.': 1,
#                           'water': 3,
#                           'right': 3,
#                           'South': 2,
#                           'hundred': 1,
#                           'morning.': 2,
#                           'store?': 1,
#                           'Spirit': 7,
#                           'water,': 1,
#                           'Earth': 6,
#                           'entire': 4,
#                           'galley?': 1,
#                           'river!': 1,
#                           'trees!': 1,
#                           'trees.': 1,
#                           'knife.': 1,
#                           'town,': 1,
#                           'canyon,': 1,
#                           'garbage!': 1,
#                           'distance.': 1,
#                           'penalty': 1,
#                           'meeting,': 1,
#                           'iceberg.': 1,
#                           'valley': 1,
#                           'world': 5,
#                           'bill!': 1,
#                           'house': 1,
#                           'bone': 1,
#                           'clouds.': 1,
#                           'Eastern': 1,
#                           'courtyard.': 1,
#                           'process': 1,
#                           'candle!': 1,
#                           'other': 1,
#                           'cellar': 1,
#                           'top,': 1,
#                           'Northern': 1,
#                           'dark.': 4,
#                           'Southern': 3,
#                           'sky?': 1,
#                           'blizzard.': 1,
#                           'pond.': 1,
#                           'Avatar': 8,
#                           'War?': 1,
#                           'labyrinth.': 1,
#                           'war': 1,
#                           'dark,"': 1,
#                           'world,': 4,
#                           'eye': 4,
#                           'city,': 2,
#                           'plants.': 1,
#                           "mayor's": 1,
#                           'west.': 1,
#                           'ceremony': 1,
#                           'power': 1,
#                           'dirt!': 1,
#                           'land.': 1,
#                           'Earth,': 1,
#                           'mud': 1,
#                           'Battle': 1,
#                           'group,': 1,
#                           'morning!': 1,
#                           'ground': 1,
#                           'past,': 1,
#                           'middle': 9,
#                           'desert!': 1,
#                           'desert.': 1,
#                           'dirt.': 1,
#                           'big': 2,
#                           'name': 4,
#                           'city': 1,
#                           'plans.': 1,
#                           'drill.': 1,
#                           'city.': 7,
#                           'Middle': 1,
#                           'back.': 1,
#                           'way.': 1,
#                           'party,': 1,
#                           'city!': 2,
#                           'wall-': 1,
#                           'library.': 1,
#                           'foam.': 2,
#                           'rear.': 1,
#                           'Water': 1,
#                           'spring': 1,
#                           'pool': 1,
#                           'most': 1,
#                           'Upper': 2,
#                           'country.': 1,
#                           'blubber.': 1,
#                           'same': 1,
#                           'first': 2,
#                           'center!': 1,
#                           'creek.': 1,
#                           'stomach.': 1,
#                           'heart.': 1,
#                           'form': 1,
#                           'chain': 1,
#                           'throat.': 1,
#                           'center': 1,
#                           'same.': 1,
#                           'box!': 1,
#                           'woods': 2,
#                           'dirt': 1,
#                           'homeland,': 1,
#                           'prison': 1,
#                           'colonies,': 1,
#                           'ballrooms': 1,
#                           'town.': 1,
#                           'shop,': 1,
#                           'polluted': 1,
#                           'night,': 1,
#                           'group': 1,
#                           'hands': 1,
#                           'family.': 2,
#                           'Dragonbone': 1,
#                           'end.': 1,
#                           'Runaway.': 1,
#                           'fireplace.': 1,
#                           'house.': 2,
#                           'forest': 1,
#                           'woods.': 1,
#                           'woods,': 1,
#                           'box.': 1,
#                           'desert,': 1,
#                           'universe.': 1,
#                           'leaf-hat?': 1,
#                           'front': 1,
#                           'subs.': 1,
#                           'middle.': 1,
#                           'heart': 1,
#                           'long': 1,
#                           'past.': 2,
#                           'last': 2,
#                           'universe\u200c?': 1,
#                           'yard.': 1,
#                           'cooler.': 2,
#                           'Boiling': 1,
#                           'cooler!': 1,
#                           'eye!': 1,
#                           'gut.': 1,
#                           'yard': 1,
#                           'escape': 1,
#                           'line-up.': 1,
#                           'very': 1,
#                           'Iceberg': 1,
#                           'nosebleed': 1,
#                           'iceberg?': 1,
#                           'sky,': 1,
#                           'art': 1,
#                           'attic,': 1,
#                           'history': 1,
#                           'good': 1,
#                           'void': 1,
#                           'next': 1,
#                           'engine': 1}),
#              'the war.': defaultdict(int,
#                          {'Two': 1,
#                           'You': 1,
#                           '\nGOW:': 1,
#                           '\nAANG:': 1,
#                           '[Aerial_': 1}),
#              'war. Two': defaultdict(int, {'years': 1}),
#              'Two years': defaultdict(int, {'ago,': 1, 'at': 1}),
#              'years ago,': defaultdict(int,
#                          {'my': 1,
#                           '[Viewers_': 1,
#                           'we': 1,
#                           'with': 1,
#                           'looking': 1,
#                           'this': 1}),
#              'ago, my': defaultdict(int, {'father': 1}),
#              'my father': defaultdict(int,
#                          {'and': 4,
#                           'thinks': 1,
#                           'now': 1,
#                           'back': 1,
#                           'not': 1,
#                           'feels': 1,
#                           'in': 1,
#                           'wanted.': 1,
#                           'to': 2,
#                           'could': 1,
#                           "hasn't": 1,
#                           'asked': 1,
#                           '-': 1}),
#              'father and': defaultdict(int,
#                          {'the': 2, 'every': 1, 'restore': 1}),
#              'the men': defaultdict(int,
#                          {'of': 2, 'who': 1, 'an': 1, 'were': 1, 'went': 1}),
#              'men of': defaultdict(int, {'my': 1, 'this': 1}),
#              'of my': defaultdict(int,
#                          {'tribe': 2,
#                           'comfort': 1,
#                           'blubbered': 1,
#                           'new': 1,
#                           'way,': 2,
#                           'blade': 1,
#                           'favorite': 3,
#                           'speech': 1,
#                           'way!': 1,
#                           'fingertips!': 1,
#                           'people.': 1,
#                           'life': 4,
#                           'hatred': 1,
#                           'father,': 2,
#                           'identity.': 1,
#                           'ring.': 1,
#                           'greatest': 1,
#                           'voice!': 1,
#                           'own': 1,
#                           'sight.': 1,
#                           'mark.': 1,
#                           'history': 1,
#                           'spare': 1,
#                           'cousin': 1,
#                           'cage': 1,
#                           'grip!': 1,
#                           'dreams,': 1,
#                           'sight': 1,
#                           'throat': 1,
#                           'senses.': 1,
#                           'inner': 1,
#                           'sight!': 1,
#                           'mind': 1,
#                           'restraint': 1,
#                           'life,': 1}),
#              'my tribe': defaultdict(int,
#                          {'journeyed': 1,
#                           'since': 1,
#                           'across': 1,
#                           'for': 1,
#                           'so': 1,
#                           'when': 1}),
#              'tribe journeyed': defaultdict(int, {'to': 1}),
#              'journeyed to': defaultdict(int, {'the': 1}),
#              'to the': defaultdict(int,
#                          {'Earth': 11,
#                           'Avatar?': 1,
#                           'last': 1,
#                           'North': 13,
#                           'prison': 2,
#                           'temple,': 1,
#                           'Fire': 22,
#                           'newest': 1,
#                           'room?': 1,
#                           'ship!': 1,
#                           'possibilities.': 2,
#                           'refurbished': 1,
#                           'challenges.': 1,
#                           'world': 1,
#                           'guards.': 1,
#                           'ships!': 1,
#                           'Capital!': 1,
#                           'village': 2,
#                           'Crescent': 1,
#                           'prize': 1,
#                           'world.': 7,
#                           'Avatar.': 1,
#                           'sanctuary.': 1,
#                           'temple.': 1,
#                           'price': 1,
#                           'hideout.': 1,
#                           'hut': 1,
#                           'dam.': 2,
#                           'town': 1,
#                           'tent?': 1,
#                           'capital': 1,
#                           'test?': 1,
#                           'great': 1,
#                           'west': 1,
#                           'ground,': 2,
#                           "man's": 1,
#                           'other': 2,
#                           'Gan': 1,
#                           'other,': 1,
#                           'future.': 1,
#                           'market.': 1,
#                           'Eastern': 3,
#                           'river,': 1,
#                           'ground!': 3,
#                           'right': 1,
#                           'river.': 1,
#                           'abbey': 1,
#                           'festival.': 1,
#                           'festival!': 1,
#                           'earth': 1,
#                           'cap,': 1,
#                           'brim': 1,
#                           'place': 1,
#                           'healing': 1,
#                           'Spirit': 2,
#                           'most': 1,
#                           'physical': 3,
#                           'mortal': 1,
#                           'oasis;': 1,
#                           'oasis': 1,
#                           'South': 1,
#                           'east': 1,
#                           'heart': 2,
#                           'point.': 1,
#                           'curse.': 1,
#                           'Royal': 3,
#                           'swamp,': 1,
#                           'swamp.': 1,
#                           'festival,': 1,
#                           'crime': 1,
#                           'neck': 1,
#                           'town!': 1,
#                           'next': 2,
#                           'earth.': 2,
#                           'living': 1,
#                           'arena."': 1,
#                           'soldiers!': 1,
#                           'ground': 1,
#                           'front.': 1,
#                           'war.': 1,
#                           'throne.': 1,
#                           'library!': 1,
#                           'sun?': 1,
#                           'waterbenders.': 1,
#                           'surface!': 1,
#                           'planetarium,': 1,
#                           'ancient': 1,
#                           'wall': 2,
#                           'city.': 1,
#                           'Avatar!': 1,
#                           'north': 1,
#                           'scene': 1,
#                           'lady': 1,
#                           'city': 1,
#                           'Outer': 3,
#                           'top': 3,
#                           'king': 1,
#                           'police': 1,
#                           'financial': 1,
#                           'commoners,': 1,
#                           'king.': 1,
#                           'king?': 2,
#                           'tip': 1,
#                           'island.': 1,
#                           'palace.': 1,
#                           'blue': 1,
#                           'horn': 1,
#                           'bathroom!': 1,
#                           'outskirts': 1,
#                           'crossroads': 1,
#                           'factory.': 1,
#                           'way': 1,
#                           'beach': 2,
#                           'Northern': 1,
#                           'future': 1,
#                           'environment': 1,
#                           'inn?': 1,
#                           'meeting.': 1,
#                           'invasion!': 1,
#                           'meeting,': 1,
#                           'Southern': 1,
#                           'invasion,': 1,
#                           'troops.': 1,
#                           'bunker.': 1,
#                           'group!': 1,
#                           'secondary': 1,
#                           'left,': 1,
#                           'truth.': 1,
#                           'submarines,': 1,
#                           'subs!': 1,
#                           'Western': 1,
#                           'list.': 1,
#                           'Hall': 1,
#                           'dragons': 1,
#                           'masters,': 1,
#                           'sacred': 1,
#                           'end.': 1,
#                           'Boiling': 2,
#                           'point,': 1,
#                           'gondolas!': 1,
#                           'war': 1,
#                           'stolen': 1,
#                           'market': 1,
#                           'actor': 1,
#                           'present': 1,
#                           'throne!': 1,
#                           'ground.': 1,
#                           'family,': 1,
#                           'water.': 1,
#                           'bomb': 1}),
#              'the Earth': defaultdict(int,
#                          {'Kingdom': 18,
#                           'Kingdom,': 2,
#                           'Kingdom.': 10,
#                           'King': 15,
#                           'King,': 2,
#                           'King!': 6,
#                           'King!"': 1,
#                           "King's": 6,
#                           'King.': 3,
#                           'King?': 2,
#                           'Chakra,': 1,
#                           "Kingdom's": 1,
#                           'Kingdom!': 2,
#                           'Kingdom?': 1}),
#              'Earth Kingdom': defaultdict(int,
#                          {'to': 1,
#                           'ship!': 1,
#                           'capital': 2,
#                           'city': 2,
#                           'waters.': 1,
#                           'town': 1,
#                           'town.': 1,
#                           'defenses': 1,
#                           'battalion?': 1,
#                           'troops': 1,
#                           'by': 1,
#                           'base': 1,
#                           'and': 1,
#                           'discovers': 1,
#                           'it': 1,
#                           'stronghold': 1,
#                           'uniforms.': 1,
#                           'girls.': 1,
#                           'prisoners?': 1,
#                           'family': 1,
#                           'are': 2,
#                           'capital\u200c?': 1,
#                           'will': 1,
#                           '...': 2,
#                           'fell!': 1,
#                           'is': 1,
#                           'colonies.': 1,
#                           'territory!': 1,
#                           'commoners.': 1,
#                           'tavern': 1,
#                           'can': 1,
#                           'shore.': 1}),
#              'Kingdom to': defaultdict(int, {'help': 1}),
#              'to help': defaultdict(int,
#                          {'fight': 1,
#                           'me': 6,
#                           'defeat': 1,
#                           'that': 1,
#                           'them.': 2,
#                           'them': 1,
#                           'stuff.': 1,
#                           'you': 6,
#                           'it': 1,
#                           'him.': 1,
#                           'him!': 1,
#                           'prove': 1,
#                           'change': 1,
#                           'unload': 2,
#                           'anyway!': 1,
#                           'us.': 1,
#                           'us': 2,
#                           'anyone': 1,
#                           'people.': 1,
#                           'us!': 1,
#                           'find': 1,
#                           'me,': 2,
#                           'you.': 4,
#                           'these': 2,
#                           'the': 1,
#                           'yourself.': 1,
#                           'Aang!': 1,
#                           'with': 1,
#                           'him': 1}),
#              'help fight': defaultdict(int, {'against': 1}),
#              'fight against': defaultdict(int, {'the': 1}),
#              'against the': defaultdict(int,
#                          {'Fire': 3,
#                           'Hei': 1,
#                           'other': 1,
#                           'general': 1,
#                           "general's": 1,
#                           'Avatar.': 1,
#                           'rocky': 1,
#                           'Earth': 1}),
#              'Fire Nation,': defaultdict(int,
#                          {'leaving': 1,
#                           'Aang.': 1,
#                           'he': 1,
#                           "aren't": 1,
#                           'just': 1,
#                           'again?': 1,
#                           "it's": 1,
#                           'but': 1,
#                           'and': 2,
#                           'it': 1,
#                           'you': 1,
#                           'did': 1,
#                           'stay': 1,
#                           'address': 1,
#                           'where': 1,
#                           'here': 1,
#                           '[Extreme_': 1,
#                           'so': 1}),
#              'Nation, leaving': defaultdict(int, {'me': 1}),
#              'leaving me': defaultdict(int, {'and': 1}),
#              'me and': defaultdict(int,
#                          {'my': 3,
#                           'Appa;': 1,
#                           'do': 1,
#                           'I': 2,
#                           'Miyuki.': 1,
#                           "I'll": 1,
#                           'the': 1,
#                           'think': 1,
#                           'there': 1,
#                           'Sokka': 1,
#                           'save': 1,
#                           'you.': 1,
#                           'telling': 1,
#                           'Katara': 1,
#                           'arrest': 1,
#                           'been': 1}),
#              'and my': defaultdict(int,
#                          {'brother': 3,
#                           'mother': 1,
#                           'entire': 1,
#                           'uncle': 1,
#                           'children': 1,
#                           'mistakes.': 1,
#                           'brothers': 1,
#                           'brother?': 1,
#                           'math': 1,
#                           'father': 1,
#                           'best': 1,
#                           "father's": 1}),
#              'my brother': defaultdict(int,
#                          {'to': 2,
#                           'and': 3,
#                           'Sensu.': 1,
#                           'abandoned': 1,
#                           "hasn't": 1}),
#              'brother to': defaultdict(int,
#                          {'look': 1,
#                           'regret': 1,
#                           'me!': 1,
#                           'you,': 1,
#                           'grab': 1}),
#              'to look': defaultdict(int,
#                          {'after': 2,
#                           'at.': 1,
#                           'for': 3,
#                           'nice,': 1,
#                           'inward': 1,
#                           'within': 1,
#                           'like!': 1,
#                           'underground!': 1,
#                           'deep': 1}),
#              'look after': defaultdict(int, {'our': 2, 'Little': 1}),
#              'after our': defaultdict(int,
#                          {'tribe.': 1, 'tribe': 1, 'battle.': 1}),
#              'our tribe.': defaultdict(int, {'Some': 1}),
#              'tribe. Some': defaultdict(int, {'people': 1}),
#              'Some people': defaultdict(int, {'believe': 1}),
#              'people believe': defaultdict(int, {'that': 1}),
#              'believe that': defaultdict(int,
#                          {'the': 1, 'you': 1, 'worked.': 1}),
#              'that the': defaultdict(int,
#                          {'Avatar': 6,
#                           'cycle': 1,
#                           'Fire': 5,
#                           'forest': 1,
#                           'guy': 1,
#                           'big-eared': 1,
#                           'festival': 1,
#                           'statue': 1,
#                           'War': 1,
#                           'secret': 1,
#                           'eclipse': 1,
#                           'playwright': 1}),
#              'Avatar was': defaultdict(int,
#                          {'never': 1,
#                           'an': 1,
#                           'here': 1,
#                           'not': 1,
#                           'actually': 1}),
#              'was never': defaultdict(int, {'reborn': 1, 'angry': 1}),
#              'never reborn': defaultdict(int, {'into': 1}),
#              'reborn into': defaultdict(int, {'the': 1}),
#              'into the': defaultdict(int,
#                          {'Air': 1,
#                           'next': 1,
#                           'Fire': 2,
#                           'reservoir--a': 1,
#                           'ground': 1,
#                           'war': 1,
#                           'eye': 1,
#                           'jewelry-making': 1,
#                           'festival.': 1,
#                           'forest,': 1,
#                           'woods.': 1,
#                           'greaseberry': 1,
#                           'sparring': 1,
#                           'Spirit': 3,
#                           'Avatar': 6,
#                           'hole!': 2,
#                           'desert.': 1,
#                           'Si': 1,
#                           'city.': 1,
#                           'torchlight': 1,
#                           'invasion': 1,
#                           'moon.': 1,
#                           'water': 1,
#                           'yard.': 1,
#                           'yard?': 1,
#                           'Earth': 1,
#                           'others.': 1}),
#              'the Air': defaultdict(int,
#                          {'Nomads': 1,
#                           'Temple.': 1,
#                           'Nation': 1,
#                           'Temples.': 1,
#                           'Nomads.': 1}),
#              'Air Nomads': defaultdict(int,
#                          {'and': 1, 'detached': 1, "didn't": 1, 'have': 1}),
#              'Nomads and': defaultdict(int, {'that': 1}),
#              'and that': defaultdict(int,
#                          {'the': 1,
#                           'means': 1,
#                           'only': 1,
#                           'egg': 1,
#                           'janitor': 1,
#                           'counts': 1,
#                           'somehow': 1}),
# ...
#                           'everyone.-': 1,
#                           'it-': 1,
#                           'them.-': 1,
#                           "Suki's.": 1}),
#              'from- it.-': defaultdict(int,
#                          {'The-': 2,
#                           'Frontal-': 1,
#                           'Fat-': 1,
#                           'Cut-': 1,
#                           'Fade-': 1}),
#              'The- boat-': defaultdict(int,
#                          {'is-': 1, 'manages-': 1, 'enters-': 1}),
#              'boat- is-': defaultdict(int, {'caught-': 1}),
#              'is- caught-': defaultdict(int,
#                          {'in-': 6, 'off-': 1, 'by-': 2, 'with-': 1}),
#              'caught- in-': defaultdict(int,
#                          {'a-': 5, 'the-': 3, 'another-': 1}),
#              'in- a-': defaultdict(int,
#                          {'rapid-': 1,
#                           'massive-': 1,
#                           'Fire-': 2,
#                           'soft-': 1,
#                           'sharp-': 1,
#                           'burst-': 1,
#                           'circular-': 10,
#                           'rather-': 1,
#                           'current-': 1,
#                           'corner-': 2,
#                           'casing-': 1,
#                           'mass-': 2,
#                           'blue-': 2,
#                           'chair-': 1,
#                           'smile-': 1,
#                           'fiery-': 2,
#                           'bag,-': 1,
#                           'line,-': 1,
#                           'leather-': 1,
#                           'similar-': 4,
#                           'street-': 1,
#                           'corner,-': 2,
#                           'semi-circle-': 1,
#                           'combination-': 1,
#                           'nearby-': 2,
#                           'mail-': 1,
#                           'tangled-': 1,
#                           'small-': 1,
#                           'moment-': 2,
#                           'large-': 6,
#                           'new-': 1,
#                           'forest.-': 2,
#                           'crowd,-': 1,
#                           'cloud.-': 1,
#                           'brotherly-': 1,
#                           'friendly-': 1,
#                           'romantic-': 1,
#                           'cloud-': 2,
#                           'purple-': 2,
#                           'pile.-': 1,
#                           'long-': 1,
#                           'pose.-': 1,
#                           'strong,-': 1,
#                           'black-': 2,
#                           'pink-': 1,
#                           'yellow-': 1,
#                           'mighty-': 1,
#                           'purplish-blue-': 1,
#                           'circle.': 2,
#                           'circle-': 6,
#                           'forest-': 2,
#                           'ball-': 1,
#                           'port.-': 1,
#                           'pool-': 1,
#                           'meditating-': 1,
#                           'reflection-': 1,
#                           'gesture-': 1,
#                           'sack.-': 1,
#                           'meditative-': 1,
#                           'dream.-': 1,
#                           'spacious-': 1,
#                           'cup.': 1,
#                           'daze,-': 1,
#                           'grassy-': 1,
#                           'globule-': 1,
#                           'prayerful-': 1,
#                           'graceful-': 1,
#                           'wondering-': 1,
#                           'box-': 2,
#                           'motherly-': 1,
#                           'chute-': 1,
#                           'stream-': 1,
#                           'trance.-': 1,
#                           'beam-': 1,
#                           'dress-': 1,
#                           "'V'-": 1,
#                           'waterbending-': 1,
#                           'pot-': 2,
#                           'gloomy-': 1,
#                           'hollow-': 1,
#                           'wooden-': 1,
#                           'tornado-': 1,
#                           'rock-': 1,
#                           'flash-': 1,
#                           'straight-': 1,
#                           'perfect-': 1,
#                           'brown-': 1,
#                           'guest-': 1,
#                           'tree.': 1,
#                           'cloak-': 1,
#                           'dark-': 2,
#                           'carriage.-': 1,
#                           'cloak.': 1,
#                           'tantalizing-': 1,
#                           'pot,-': 1,
#                           'clearing-': 1,
#                           'rocky-': 1,
#                           'mountainous-': 1,
#                           'dream-': 2,
#                           'prairie-': 1,
#                           'single-': 1,
#                           'different-': 2,
#                           'whirlpool-': 1,
#                           'thin-': 1,
#                           'pet-': 1,
#                           'very-': 1,
#                           'crouching-': 1,
#                           'mess.-': 1,
#                           'sauna-': 1,
#                           'circle.-': 4,
#                           'costume-': 1,
#                           'flashback.-': 2,
#                           'group-': 1,
#                           'sympathetic-': 1,
#                           'mirror.-': 1,
#                           'room,-': 1,
#                           'prison-': 1,
#                           'lightning-': 1,
#                           'square-': 1,
#                           'lake-': 2,
#                           'town.-': 1,
#                           'crock.': 1,
#                           'sword-': 1,
#                           'team-': 1,
#                           'dream.': 1,
#                           'stance-': 1,
#                           'puddle-': 1,
#                           'cooking-': 1,
#                           'sitting-': 1,
#                           'comical-': 1,
#                           'fighting-': 1,
#                           'chain.-': 1,
#                           'mountain-': 1,
#                           'topknot.-': 1,
#                           'twister-': 1,
#                           'snake-': 1,
#                           'metal-': 1,
#                           'direction.': 1,
#                           'wide-': 1,
#                           'forested-': 1,
#                           'flashback-': 1,
#                           'synchronized-': 1,
#                           'circle,-': 1,
#                           'position.-': 1,
#                           'spot.-': 1,
#                           'fit-': 1,
#                           'slumber.\nCuts-': 1,
#                           'ponytail.-': 1,
#                           'frantic-': 1,
#                           'tree.-': 1,
#                           'pile-': 1}),
#              'a- rapid-': defaultdict(int, {'current,-': 1, 'flashback-': 1}),
#              'rapid- current,-': defaultdict(int, {'which-': 1}),
#              'current,- which-': defaultdict(int, {'is-': 1}),
#              'which- is-': defaultdict(int,
#                          {'pulling-': 1,
#                           'now-': 4,
#                           'overheard-': 1,
#                           'nearly-': 1,
#                           'sticking-': 1,
#                           'completely-': 1,
#                           'the-': 2,
#                           'filled-': 1,
#                           'sliced-': 1,
#                           'lined-': 1,
#                           'a-': 2,
#                           'about-': 1,
#                           'bustling-': 1,
#                           'kicked-': 1,
#                           'revealed-': 1,
#                           'quickly-': 1,
#                           'pulled-': 1}),
#              'is- pulling-': defaultdict(int, {'it-': 1}),
#              'pulling- it-': defaultdict(int, {'swiftly-': 1, 'out.-': 1}),
#              'it- swiftly-': defaultdict(int, {'toward-': 1}),
#              'swiftly- toward-': defaultdict(int, {'a-': 1, 'him.-': 1}),
#              'toward- a-': defaultdict(int,
#                          {'jumble-': 1,
#                           'small-': 2,
#                           'door-': 2,
#                           'fisherman-': 1,
#                           'waiting-': 1,
#                           'large-': 1,
#                           'mountain-': 1,
#                           'single-': 1,
#                           'cavern-': 1,
#                           'temple-': 1,
#                           'helpless-': 1,
#                           'wagon-': 1,
#                           'shop-': 1,
#                           'curtain-': 1,
#                           'wall.-': 1,
#                           'stone-': 1}),
#              'a- jumble-': defaultdict(int, {'of-': 1}),
#              'jumble- of-': defaultdict(int, {'large-': 1}),
#              'of- large-': defaultdict(int,
#                          {'icebergs-': 1, 'doors.-': 1, 'rocks.-': 1}),
#              'large- icebergs-': defaultdict(int, {'which-': 1, 'and-': 1}),
#              'icebergs- which-': defaultdict(int, {'block-': 1, 'slam-': 1}),
#              'which- block-': defaultdict(int, {'the-': 1}),
#              'block- the-': defaultdict(int,
#                          {'end-': 1,
#                           'attack.-': 1,
#                           'running-': 1,
#                           'attacks,-': 1,
#                           'statues.-': 1,
#                           'view-': 1,
#                           'attack-': 1,
#                           'attack,-': 1,
#                           'entranceway.-': 1}),
#              'the- narrow-': defaultdict(int, {'passage-': 1}),
#              'narrow- passage-': defaultdict(int, {'formed-': 1}),
#              'passage- formed-': defaultdict(int, {'by-': 1}),
#              'formed- by-': defaultdict(int, {'the-': 1}),
#              'the- towering-': defaultdict(int, {'walls-': 1, 'iceberg-': 1}),
#              'towering- walls-': defaultdict(int, {'of-': 1}),
#              'of- ice.-': defaultdict(int,
#                          {'Sokka-': 2,
#                           'He-': 2,
#                           'Cut-': 2,
#                           'As-': 1,
#                           'Katara-': 1}),
#              'ice.- Sokka-': defaultdict(int, {'paddles-': 1, 'runs-': 1}),
#              'Sokka- paddles-': defaultdict(int, {'the-': 1}),
#              'paddles- the-': defaultdict(int, {'boat-': 2}),
#              'boat- in-': defaultdict(int, {'an-': 1}),
#              'in- an-': defaultdict(int,
#                          {'attempt-': 23,
#                           'ice-': 1,
#                           'awkward-': 1,
#                           'alleyway.-': 1,
#                           'oddly-': 1,
#                           'icy-': 1,
#                           'unknown-': 2,
#                           'outdoor-': 1,
#                           'alley.-': 3,
#                           'arc-': 1,
#                           'earth-': 2,
#                           'instant.': 1,
#                           'alley,-': 1,
#                           'elaborate-': 1,
#                           'extreme-': 1,
#                           'isolated-': 1,
#                           'interrogation-': 1}),
#              'an- attempt-': defaultdict(int, {'to-': 24}),
#              'attempt- to-': defaultdict(int,
#                          {'stay-': 1,
#                           'hold-': 1,
#                           'whip-': 1,
#                           'throw-': 1,
#                           'impress-': 1,
#                           'get-': 5,
#                           'look-': 1,
#                           'spear-': 1,
#                           'slow-': 2,
#                           'avoid-': 1,
#                           'comfort-': 2,
#                           'scare-': 1,
#                           'drag-': 1,
#                           'catch-': 1,
#                           'speak.-': 1,
#                           'hinder-': 1,
#                           'steady-': 1,
#                           'strike-': 1,
#                           'save-': 1,
#                           'heal-': 1,
#                           'halt-': 1,
#                           'fend-': 1,
#                           'stop-': 1,
#                           'deflect-': 1,
#                           'budge-': 1,
#                           'blast-': 1,
#                           'break-': 1}),
#              'to- stay-': defaultdict(int,
#                          {'clear-': 2,
#                           'behind-': 1,
#                           'away-': 1,
#                           'above-': 2,
#                           'aboard-': 1}),
#              'stay- clear-': defaultdict(int, {'of-': 2}),
#              'clear- of-': defaultdict(int, {'any-': 1, 'some-': 1}),
#              'of- any-': defaultdict(int, {'floating-': 1, 'other-': 1}),
#              'any- floating-': defaultdict(int, {'chunks-': 1}),
#              'floating- chunks-': defaultdict(int, {'of-': 1}),
#              'chunks- of-': defaultdict(int,
#                          {'ice.-': 3, 'ice-': 1, 'rock-': 3}),
#              'ice.- He-': defaultdict(int,
#                          {'manages-': 1,
#                           'lies-': 1,
#                           'suddenly-': 1,
#                           'cuts-': 1}),
#              'He- manages-': defaultdict(int, {'to-': 4}),
#              'manages- to-': defaultdict(int,
#                          {'gain-': 1,
#                           'stay-': 2,
#                           'miss-': 1,
#                           'escape,-': 1,
#                           'dissipate-': 1,
#                           'grab-': 3,
#                           'deflect-': 1,
#                           'regain-': 1,
#                           'grasp-': 2,
#                           'spin-': 1,
#                           'evade-': 1,
#                           'climb-': 1,
#                           'get-': 6,
#                           'avoid-': 2,
#                           'pull-': 1,
#                           'remove-': 1,
#                           'back-flip-': 1,
#                           'slip-': 2,
#                           'escape-': 1,
#                           'push-': 3,
#                           'scrape-': 1,
#                           'narrowly-': 1,
#                           'capture-': 1,
#                           'break-': 1,
#                           'produce-': 1,
#                           'destroy-': 1,
#                           'deflect.-': 1,
#                           'prop-': 1,
#                           'strike-': 1,
#                           'conjure-': 1,
#                           'defeat-': 1,
#                           'block-': 1,
#                           'vaporize-': 1,
#                           'send-': 1,
#                           'reach-': 1,
#                           'steady-': 1,
#                           'dodge-': 4,
#                           'dodge.-': 1,
#                           'redirect-': 1,
#                           'slow-': 1}),
#              'to- gain-': defaultdict(int, {'just-': 1}),
#              'gain- just-': defaultdict(int, {'enough-': 1}),
#              'just- enough-': defaultdict(int, {'speed-': 1}),
#              'enough- speed-': defaultdict(int, {'to-': 1}),
#              'speed- to-': defaultdict(int, {'keep-': 1}),
#              'keep- the-': defaultdict(int,
#                          {'boat-': 1, 'secret-': 1, 'rocks-': 1, 'tank-': 1}),
#              'boat- from-': defaultdict(int, {'being-': 1}),
#              'from- being-': defaultdict(int, {'crushed-': 1, 'blown-': 1}),
#              'being- crushed-': defaultdict(int, {'by-': 1}),
#              'crushed- by-': defaultdict(int,
#                          {'two-': 1, 'the-': 1, 'some-': 1}),
#              'two- icebergs-': defaultdict(int, {'which-': 1}),
#              'which- slam-': defaultdict(int, {'together-': 1}),
#              'slam- together-': defaultdict(int, {'behind-': 1}),
#              ...})

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
for i in range(100):
    probability_of_next_word = np.array(list(next_word2[current_word_1+' '+current_word_2].values()))/word_used2[current_word_1+' '+current_word_2]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2 = current_word_2,np.array(list(next_word2[current_word_1+' '+current_word_2].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_2.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. Long ago, the four elements! I'll need more food. [Slams the torch into his arms.] You brought this on your guys' side! [Pauses for a second glance.]
# BATO: For this is just mud!
# ORACLE: [Quizzically.] So ... how about these? [Frontal view of Zuko over Iroh's shoulder.] I know what happened to the Fire Lord Ozai is a Water Tribe peasant!
# AANG: Yeah, but I knew you would enjoy hearing some history. [Fades to show Aang.] was my fault. [The three teenagers looks surprised at Aang's words. The camera fades to the gondola briefly as we see

# %%
word_used3 = defaultdict(int)
next_word3 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-3]):
    word_used3[word+' '+words[i+1]+' '+words[i+2]] += 1
    next_word3[word+' '+words[i+1]+' '+words[i+2]][words[i+3]] += 1

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
current_word_3 = "Earth."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
print(current_word_3, end=' ')
for i in range(100):
    probability_of_next_word = np.array(list(next_word3[current_word_1+' '+current_word_2+' '+current_word_3].values()))/word_used3[current_word_1+' '+current_word_2+' '+current_word_3]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2,current_word_3 = current_word_2,current_word_3,np.array(list(next_word3[current_word_1+' '+current_word_2+' '+current_word_3].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_3.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. Long ago, the four nations lived together in harmony. Then, everything changed when the Fire Nation invaded his home, he'll be devastated.
# AANG: [Happily.] Hey guys! [The two look up and see Aang standing in front of Katara and Sokka look at each other.]
# SCENE DESCRIPTION: In a prison, Long Feng is visibly seated in front of him to block his exit.
# AANG: [Sokka and Aang shake hands and the group hugs.]
# TOPH: I hope you never have to see to be lucky.
# SCENE DESCRIPTION: The group gets Appa and brings him in. He opens his eyes but

# %%
from collections import Counter, defaultdict
characters = Counter("\n"+avatar.character.str.upper().str.replace(' ','.')+":")

nested_dict = lambda: defaultdict(nested_dict)
word_used2C = nested_dict()
next_word2C = nested_dict()

for i,word in enumerate(words[:-2]):
    
    if word in characters:
        character = word
        
    if character not in word_used2C:
        word_used2C[character] = dict()
    if word+' '+words[i+1] not in word_used2C[character]:
        word_used2C[character][word+' '+words[i+1]] = 0
    word_used2C[character][word+' '+words[i+1]] += 1

    if character not in next_word2C:
        next_word2C[character] = dict()
    if word+' '+words[i+1] not in next_word2C[character]:
        next_word2C[character][word+' '+words[i+1]] = dict()
    if words[i+2] not in next_word2C[character][word+' '+words[i+1]]:
        next_word2C[character][word+' '+words[i+1]][words[i+2]] = 0
    next_word2C[character][word+' '+words[i+1]][words[i+2]] += 1

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
for i in range(100):
    if current_word_1 in characters:
        character = current_word_1

    probability_of_next_word = np.array(list(next_word2C[character][current_word_1+' '+current_word_2].values()))/word_used2C[character][current_word_1+' '+current_word_2]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2 = current_word_2,np.array(list(next_word2C[character][current_word_1+' '+current_word_2].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_2.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother used to tell the Earth Kingdom. And then they kicked your butt.
# SCENE.DESCRIPTION: Cut to a sideshot of the harbor as the guards stop the flow of slurry is released from his feet. At the invasion, the team is situated at the view. Cuts to the blue dragon coming out of the floor, a man towering over Aang, causing tiny arrows to fly forward on foot again, using airbending to knock her to go out the tent through the dark tunnel where several soldiers on one floe among dozens.
# Katara, shuffling on her head.
# YOUNG.AZULA: [Offcamera.]
